# %% [markdown]
# # IMPORTS

# %%
import re 
import os
import tweepy 
import pandas as pd
from tweepy import OAuthHandler 
from textblob import TextBlob

# %% [markdown]
# # Get Credentials
#
#     credentials are required for the tweepy api which allows us extract tweets from twitter.
#     In order to extract tweets we need a developer account in twitter and they provide us with four keys
#     these four keys are unique for each user and i have saved my keys in a text file 'Credential.txt'
#
#     if you dont want to save your access keys just copy paste the access keys as strings
#     ex:
#     consumer_key = "XXXXXXXXXXXXXXXXXXX'
#     consumer_secret = "XXXXXXXXXXXXXXX'
#     access_key = 'XXXXXXXXXXXX'
#     access_secret = 'XXXXXXXXXXX'
#
#     Note:
#     Python reads the newline characters as well in text files.
#     So to Exclude the newline charecters from keys we used ".rstrip()"

# %%
keyFile = open('Credentials.txt', 'r')
consumer_key = keyFile.readline().rstrip() 
consumer_secret = keyFile.readline().rstrip()
access_key = keyFile.readline().rstrip()
access_secret = keyFile.readline().rstrip()
keyFile.close()

# %% [markdown]
# # Authentication
#
#     connecting with the tweepy Api

# %%
try: 
    # create OAuthHandler object 
    auth = OAuthHandler(consumer_key, consumer_secret) 
    # set access token and secret 
    auth.set_access_token(access_key, access_secret)
    # create tweepy API object to fetch tweets 
    api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify= True) 
except: 
    print("Error: Authentication Failed")

# %% [markdown]
# # Extract Tweets Using a Keyword

# %% [markdown]
# # Function For cleaning Tweets
#
#     removing special charecters, hyperlinks,user names , numbers  etc.
#     using simple regular expression statements.
#     this is needed as the cleaned tweet is fed to Text blob model which gives us a sentiment using sentiment polarity.
#     so by this method we create a data set with tweets and their respective sentiments (as labels)
#     this dataset is the used to train our classification algorithm.

# %%
def clean_tweet(tweet): 
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(#[0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %% [markdown]
# # Function to get Tweet Sentiment
#
#     the function classifies sentiment of passed tweet using textblob's sentiment method

# %%
def get_tweet_sentiment(tweet): 
    
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(clean_tweet(tweet)) 
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %% [markdown]
# # Get the Tweets And append in list along with its attributes

# %%
tweets_list = []  # empty list for collecting tweets
# list containing serach query for which we want related tweets
text_query = ["Donald Trump -filter:retweets","Joe Biden -filter:retweets","Bitcoin -filter:retweets","Barack Obama -filter:retweets","Election 2020 -filter:retweets","Corona Virus -filter:retweets","Black lives matter -filter:retweets","IPL 2020 -filter:retweets","Arnab Goswami -filter:retweets","Champions league -filter:retweets","first presidential debate -filter:retweets"]

# %%
for key in text_query:
    tweets = tweepy.Cursor(api.search, q=key)
    for tweet in api.search(q=key,count= 100,tweet_mode = 'extended',lang="en"):   #extended gives us the entire tweet , by deafult tweets are truncated
        sentiment = get_tweet_sentiment(tweet.full_text)
        tweets_list.append((tweet.id,tweet.created_at,tweet.user.name,tweet.full_text,sentiment))

# %% [markdown]
# # Api.search returns 15 tweets per search keyword
#
#     default : 15 tweets ; max : 100

# %%
len(tweets_list)
# Out:
# 1100

# %%
df = pd.DataFrame(tweets_list,columns = ['ID' , 'Date- Time', 'User_Name','Tweet','Sentiment'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 5 columns):
# ID            1100 non-null int64
# Date- Time    1100 non-null datetime64[ns]
# User_Name     1100 non-null object
# Tweet         1100 non-null object
# Sentiment     1100 non-null object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage:
# 41  @niaimanofficial @agilegrrl @AnnihilaterAnus @JohnGaltJunior3 @realDonaldTrump WHAT HUMAN RIGHTS ARE SACRIFICED UNDER DONALD TRUMP
# 42  donald trump is a fucking joke
# 43  Donald Trump cheated his way into the White House. He’s mad he cant lie and cheat his way there again. We have spoken AGAIN and we don’t want him in our White House. He’s been illegitimate and a liar. @HillaryClinton BEAT HIM... and @JoeBiden is going to beat him!!!
# 44  Donald Trump WOKE UP FEELING HUNGRY🍊\n\n0 VOTES😱😱😱\nBlew a 3-1 lead to a sleepy joe🥶🥶🥶\n5 tweets😈😈😈\nUnemployed in 2 months😹😹😹\n0 Mail In Ballots 😳😳😳😳\nWon Utah 💯💯💯\nLosing Popular Vote 👑👑👑👑\n15 Tweets ✅✅✅✅\n\nBest president of all time? 🥴🥴🥴
# 45  @KMCRadio “ Stop counting the votes “\n\n Donald Trump\n\nSo that’s the problem for @realDonaldTrump .   People voting. https://t.co/3mYW8oKOff
# 46  @Franklin_Graham Pray for Donald Trump to win Nevada🙏🏻🙏🏻🙏🏻
# 47  Hey @Twitter, you've had to take down two of Donald Trump's false election tweets in the past hour, and now he's just posted several more false  tweets. Trump is breaking all the election rules. It's time to temporarily suspend his account until the election results are in. https://t.co/cqgFP5DN2P
# 48  @DebraMessing 12:05 p.m. ET\n\nPresidential odds have remained quiet for the past two hours, with Joe Biden now -500 against Donald Trump.\n\nHere’s where the betting market stands just past noon ET on Wednesday:\n\n    Donald Trump: +430 (18.5% chance)\n    Joe Biden: -500 (81.5% chance)
# 49  Bernie Sanders accurately predicted Trump's election reaction https://t.co/2CO1cr1nuL
#
#    Sentiment
# 0   negative
# 1   negative
# 2   neutral
# 3   neutral
# 4   positive
# 5   positive
# 6   negative
# 7   positive
# 8   neutral
# 9   positive
# 10  positive
# 11  neutral
# 12  negative
# 13  neutral
# 14  negative
# 15  positive
# 16  positive
# 17  neutral
# 18  negative
# 19  positive
# 20  positive
# 21  negative
# 22  negative
# 23  positive
# 24  neutral
# 25  neutral
# 26  positive
# 27  negative
# 28  negative
# 29  negative
# 30  neutral
# 31  positive
# 32  neutral
# 33  positive
# 34  positive
# 35  neutral
# 36  neutral
# 37  neutral
# 38  neutral
# 39  neutral
# 40  neutral
# 41  neutral
# 42  negative
# 43  negative
# 44  positive
# 45  neutral
# 46  positive
# 47  negative
# 48  negative
# 49  positive

# %% [markdown]
# # Save the content of the dataframe in a csv file

# %%
# if file does not exist write header 
if not os.path.isfile('Tweetlabelled.csv'):
   df.to_csv('Tweetlabelled.csv', header='column_names',index=False)
else: # else it exists so append without mentioning the header
   df.to_csv('Tweetlabelled.csv', mode='a', header=False,index=False)

# %%
# Display the csv file and check its contents

# %%
View_tweets = pd.read_csv("Tweetlabelled.csv")

# %%
View_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
# 30495  Murica 🇺🇸
# 30496  Big B
# 30497  Jay Kirell
# 30498  Bahoz (buh•whoz)
# 30499  Lacey Sousa
# 30500  On The LO LO
# 30501  Jim Mallett 🇨🇦
# 30502  Carla Marinucci
# 30503  Optimum Bliss
# 30504  fia🌪
# 30505  🌞Silly Lady🍯
# 30506  𝘽𝙤𝙗 𝙅𝙤𝙨𝙚𝙥𝙝
# 30507  DavidG
# 30508  thecompanytheatre
# 30509  Caleb Howe
# 30510  Alex Fluffy Wise
# 30511  Chris Wallace
# 30512  DiasporAfri
# 30513  Ndidi Love
# 30514  Amy Giannotti, MS, CLM
# 30515  consigliere
# 30516  Mickey/Mick/Michelle
# 30517  Jessica Nicholson
# 30518  Justin Secor 🌹
# 30519  John Guardiano
# 30520  Bradley Wascher
# 30521  Chalkbeat
# 30522  Brian Miller
# 30523  Julia Pyper
# 30524  🔞😈𝕹𝖊𝖒𝖎𝖘 𝖃𝖚𝖊😈🔞 ENVTuber
# 30525  Brad Taylorade
# 30526  Scott Fillner
# 30527  Don Carlos Collazo Miranda Jr-Not a Public Figure:
#
#                                                                                                                                                                                                                                                                                                                          Tweet  \
# 30478  @coolp1np Joe Biden: \n- "He’s elected to the next election."\n\nFirst Presidential Debate 2020
# 30479  Today, was the first time ever voring. Waiting for the results from this presidential debate debate. #Election2020 #HarlowF20
# 30480  @Drizzy__Drae @JoeBiden I had to block some of these Trump supporters after the first presidential debate and then I got into a fight today at the polls with this lady that had a Trump hat and told me to vote for him. I told her that I vote for whoever I want to vote
# 30481  This is Too on the nose, but my first political memory is watching a presidential debate at age 5 or 6, sitting on the foot of my parents' bed, and saying that I wanted Jesse Jackson to be president because I thought it would be good for America to have a Black president
# 30482  I can't believe yall really votes for trump after the first presidential debate
# 30483  @satboi10 @Mavis87Williams @NotSuperIsTaken @WorshipLordElmo during the first presidential debate when he said "Proud Boys stand back and stand by" when asked to denounce white supremacy.  Don't argue if you're obviously not educated.
# 30484  "DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/QUjStnOhSK via @YouTube
# 30485  during the first presidential debate.. you already know biden wanted to pimp slap trump for talking bad bout his son. shiiii i woulda done the same thing. i feel for biden. \n\n#BidenHarris2020 💙
# 30486  my PBS app just started replaying the screaming match from the first presidential debate for no apparent reason and that has caused my blood pressure to spike like just about nothing else tonight
# 30487  PBS just said “first presidential debate” and my history loving ass thought they were gonna show Nixon and Kennedy but they just showed trump and biden interrupting each other
# 30488  "DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/mqe3VfWEHR via @YouTube
# 30489  "DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/az1BoMmw16 via @YouTube
# 30490  the first presidential debate (AJMV)
# 30491  @sza watched it after the first presidential debate, felt about right
# 30492  @Cre8veJessica @ImBrendanKing @CBS6 Really, I can.  After that first presidential debate, I didnt want to vote for either candidate. If it wasnt for those two ballot measures. I might have skip voting this election as well and fyi I have voted in every election since I was able.
# 30493  @Amanda9J @KirkMedas He literally said it in the first presidential debate. At this point you’re choosing not to acknowledge the truth. Why would the whole world lie and make that up? Here’s the proof directly in your face. https://t.co/CocT8VKY1Y
"DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/9IsXAXfuqO Just sent to me by a friend. Funny!! @_WendyJenks @bec_susan @relizgott @RachelPeyton2
# 30517  I was so anxious &amp; upset during the first presidential debate that I drank until I got sick. It’s safe to say my liver is lucky that I have to work tonight.
# 30518  The memes during the first presidential debate were unrivaled https://t.co/3fQhqJMl37
# 30519  …In fact, #Trump was so undisciplined &amp; so scattershot misguided in his attacks on #Biden that his efforts almost constitute a textbook example of how to lose a presidential race. His first debate performance was  complete fiasco... https://t.co/ejrfUGyASF
# 30520  One remarkable part of 2020 is just how stable the polls were.\n\nThe first presidential debate, happening two nights before Trump's covid-19 diagnosis, was one event that coincided with polling moment — but even then, it was below average.\n\nRead more:\nhttps://t.co/GLdScqFoG7\n\n6pm/ https://t.co/lfyS3ziXDn
# 30521  First Person: Watching the candidates square off seemed like meaningful homework. I realize now that young people have more pressing assignments. #ElectionDay #Election2020 #EdChat #k12 https://t.co/F7lu5CH2Cp
# 30522  @realDonaldTrump Kellyanne Conway ran the best campaign in history.  She was the first woman to run and win a Presidential campaign.  She was gold.  Did you hire Clintons team for 2020?  I don't get the strategy at all.  You run from second debate.  A TV debate.  YOU'RE A TV STAR!  YOU GO ON NBC!
# 30523  * Aug. 28 (post-Republican National Convention): Trump 45.4%; Biden 49.6%\n\n* Sept. 29 (post-first debate): Trump 39.4%; Biden 61.73%\n\n* Oct. 22 (post-second debate): Trump 33.5%; Biden 65.2%\n\nSource: https://t.co/7JA97UMKj5
# 30524  This makes more sense then the real thing..😈\n"DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/hHwxWrsxzB via @YouTube
# 30525  If your first time watching a Presidential debate was in 2020 your political opinion is just peanuts to an elephant. STFU
# 30526  "DEBATE NIGHT 2020!" — A Bad Lip Reading of the First Presidential Debat... https://t.co/w9aNoROFaC via @YouTube Laughrer is always good for the nerves
# 30527  Trump's first presidential debate in 2015 ended with him attacking then-Fox News journalist Megyn Kelly. last debate ended with him thanking the journalist for saying he won his face-off against Joe Biden "handily." \nRACIST BIRDS OF THE SAME FEATHER'' Flock together. https://t.co/a6AQMdZumA
#
#       Sentiment
# 30478  positive
# 30479  positive
# 30480  positive
# 30481  positive
# 30482  positive
# 30483  positive
# 30484  negative
# 30485  negative
# 30486  positive
# 30487  positive
# 30488  negative
# 30489  negative
# 30490  positive
# 30491  positive
# 30492  positive
# 30493  positive
# 30494  positive
# 30495  positive
# 30496  negative
# 30497  positive
# 30498  positive
# 30499  negative
# 30500  positive
# 30501  negative
# 30502  positive
# 30503  positive
# 30504  positive
# 30505  positive
# 30506  positive
# 30507  positive
# 30508  negative
# 30509  positive
# 30510  positive
# 30511  positive
# 30512  positive
# 30513  positive
# 30514  positive
# 30515  negative
# 30516  negative
# 30517  positive
# 30518  positive
# 30519  positive
# 30520  positive
# 30521  positive
# 30522  positive
# 30523  positive
# 30524  positive
# 30525  positive
# 30526  positive
# 30527  positive

# %% [markdown]
# # how to collect tweets :
#
#         run the multiple times with differnt keywords or serach queries.
#         The final csv file will now contain all tweets that we extracted from differnt keywords, however
#         it is possible that two differnt queries can give as the same tweet .
#         for example virat kholi and cricket may give us same tweets
#         so the csv file will contain duplicates and we need to delete those dplicate entries from our csv file or dataset.
