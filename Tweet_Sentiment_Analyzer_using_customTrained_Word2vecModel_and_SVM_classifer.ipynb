# %% [markdown]
# # IMPORTS:

# %%
import pandas as pd
import numpy as np
import re
import string
import emoji
import matplotlib.pyplot as plt

from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim.models.word2vec import Word2Vec

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

# %matplotlib inline

# %% [markdown]
# # Setting this so we can see the full content of cells
#      run cell below only once

# %%
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Load And analyse the dataset we created by extracting tweets from twitter using Tweepy API

# %%
tweets = pd.read_csv('TweetlabelledFinal.csv')
tweets.head(50)
# Out:
#                      ID           Date- Time  \
# 0   1286896213657346050  2020-07-25 05:29:01
# 1   1286905185273610241  2020-07-25 06:04:40
# 2   1287391022218006531  2020-07-26 14:15:12
# 3   1287495418180501505  2020-07-26 21:10:02
# 4   1287731665452769280  2020-07-27 12:48:48
# 5   1287756489428353025  2020-07-27 14:27:27
# 6   1287756655413911554  2020-07-27 14:28:06
# 7   1287773079675056128  2020-07-27 15:33:22
# 8   1287775000041271296  2020-07-27 15:41:00
# 9   1287808107817689090  2020-07-27 17:52:33
# 10  1287843946354421761  2020-07-27 20:14:58
# 11  1287884531136110592  2020-07-27 22:56:14
# 12  1287892477765197826  2020-07-27 23:27:49
# 13  1287904129663328259  2020-07-28 00:14:07
# 14  1287927637235519489  2020-07-28 01:47:31
# 15  1287988053777084416  2020-07-28 05:47:36
# 16  1288005340609441792  2020-07-28 06:56:17
# 17  1288015938000793602  2020-07-28 07:38:24
# 18  1288043573481373696  2020-07-28 09:28:13
# 19  1288062050439028741  2020-07-28 10:41:38
# 20  1288065092605448192  2020-07-28 10:53:43
# 21  1288071955820810242  2020-07-28 11:21:00
# 22  1288089178077401088  2020-07-28 12:29:26
# 23  1288109458699063296  2020-07-28 13:50:01
# 24  1288180961432211457  2020-07-28 18:34:09
# 25  1288181236956004358  2020-07-28 18:35:14
# 26  1288212346880622592  2020-07-28 20:38:51
# 27  1288214928030146560  2020-07-28 20:49:07
# 28  1288215722930442240  2020-07-28 20:52:16
# 29  1288237381850726400  2020-07-28 22:18:20
# 30  1288273299156406272  2020-07-29 00:41:04
# 31  1288311678791122945  2020-07-29 03:13:34
# 32  1288341917126852609  2020-07-29 05:13:43
# 33  1288357300315488258  2020-07-29 06:14:51
# 34  1288400271492751360  2020-07-29 09:05:36
# 35  1288423124170674176  2020-07-29 10:36:25
# 36  1288443082178850816  2020-07-29 11:55:43
# 37  1288455407795544065  2020-07-29 12:44:42
# 38  1288486550607716354  2020-07-29 14:48:27
# 39  1288529634762436613  2020-07-29 17:39:39
# 40  1288541833744850945  2020-07-29 18:28:07
# 41  1288562484450910211  2020-07-29 19:50:11
# 42  1288589160530489346  2020-07-29 21:36:11
# 43  1288620664514060288  2020-07-29 23:41:22
# 44  1288628912474460160  2020-07-30 00:14:08
# 45  1288638228841496582  2020-07-30 00:51:10
# 46  1288638535738765312  2020-07-30 00:52:23
# 47  1288650866770182152  2020-07-30 01:41:23
# 48  1288683094816329730  2020-07-30 03:49:27
# 49  1288708165895368705  2020-07-30 05:29:04
#
#                                User_Name  \
# 0   BALLl
# 1   T:HE:JAMES. HMRH
# 2   Anshi Pathak
# 3   Goodauld69th
# 4   Sardar Khan
# 5   guapdaddy 3000
# 6   who?????me
# 7   The Great Gay Trainwreck
# 8   Dawood Javed
# 9   Xavier Dolanigga
# 10  Nasser_Alsaadi🇶🇦
# 11  ☣Woke⚔Slayer☣2.0🇮🇳
# 12  bdsmmia 💋 Taking Bookings for August
# 13  Harry Potter Reveals Bot
# 14  Albus Dumbledore
# 15  Madhumita Banerjee
# 16  🌟 런디의 1주년을 축하드려요🌟
# 17  Amanulla Hashmi
# 18  𝑳𝙰𝚄𝚁𝙴𝙽 birthday in 2 days 😹
# 19  NAMO
# 20  can you think?
# 21  Angelic disaster 🇦🇷 bite-sized 🐻🧀🍻🥚
# 22  Omar
# 23  JENNIFER Hall
# 24  Gellert Grindelwald
# 25  Affordable Housing Uganda
# 26  Son of Abraham
# 27  Harry Parallels
# 28  Goodauld69th
# 29  sanjayusername
# 30  Dr. Mohib Wazir🇵🇰
# 31  Alex
# 32  dylan morrison
# 33  JENNIFER Hall
# 34  karenchristinabeal
# 35  trish Grindstaff
# 36  Indian Air Warrior
# 37  雨戸ナゲ狐犬
# 38  Fazal Malik
# 39  जीनेष शाह - 💯% फोलो बेक
# 40  sanjayusername
# 41  Goodman Mlalazi
# 42  trump#1prez
# 43  Team the Ghost of Socks Clinton
# 44  Harry Potter Reveals Bot
# 45  Tina
# 46  Cullen Walser
# 47  Dr Sreekumar
# 48  shreyaa
# 49  MulTipleEffect
#
#                                                                                                                                                                                                                                                                                                                                 Tweet  \
# 0   i need to make my own SapceX, some people dont deserve to live here
# 1   Thre was mention of this earlier, the infraction on the views of the cosmos from the SapceX array and how astronomy would compensate. https://t.co/I5omeFq4SM
# 2   @bhab005 @KanganaTeam @kunalpande8 Sachine Tendulkar handle his account and but here kangana team handles her. That's the difference here. And if she is doing that what's funny. She has earned that right. Also Jo log khud nahi bolte h wo dusron se bulwate Hain. Wo khud bol rahi h to galat. Kya h.
# 3   Mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   @gareebscientist @GauravG91 @Chandel1402 @isro @SpaceX He I mean... Vaibhav....spacex is doing great work.. But its unfair to compare two.. No offense to sapcex but I will chose ISRO over spacex AnyDay....
# 5   someone get me the panda pegion nike sb
# 6   Piers Morgan, A Scum Media "Star" Showing His Spitefull Side. What a Pathetic Little Man. https://t.co/fKIRzd7aGE
# 7   Old PC game skyboxes emit such elegiac auras\njust look at like\nThe skybox from the Harry potter 2 qudditch area
# 8   "Fantastic Beasts: The Crimes of Grindelwald, Gellert Grindelwald plans to raise an army of wizards to rule over non-magical beings. In response, Newt Scamander's former professor, Albus Dumbledore, seeks his help to stop him."\n#FantasticBeastsTheCrimesOfGrindelwald https://t.co/KmVVV9z7FB
# 9   @Selinakyle981 @filmsbyzoe also Kit Harrigton is good in this movie. I don't care what anybody says.
# 10  @fighterpics His excellency pegion a tragic loss we wont forget about
# 11  @KyleKulinski You think it's not a problem!!? \nDamn what a pegion holed murrican....
# 12  Pegion https://t.co/sEMQkMukGO
# 13  J.K. Rowling reveals Gellert Grindelwald actually had aquamarine eyes, short hair, and a bossy personality.
# 14  I was most famous for my defeat of Gellert Grindelwald, the discovery of the twelve uses of Dragon's Blood, and my work on alchemy with Nicolas Flamel
# 15  #CBICrucialForSSR\n@adityathakekar \n@Arnab_goshwamii \n@iujjawaltrivedi \nADITYA THAKREY  WHY YOU ARE BLOCKING THE TWITTER ACCOUNT OF EVERYBODY WHO IS TWEETING YOU? BETA  WHY ARE YOU SO SCARED? AS AN YOUTH, COME OUT FROM YOUR PEGION WHOLE N DEMAND CBI PROBE FOR YOUR FRIEND SUSHANT.
# 16  i've read qudditch legend renjun, volleyball setter renjun, and baseball captain renjun but never basketball player jun 💔
# 17  @ParveenKaswan Pegion ... https://t.co/OS6Ou6FeoI
# 18  @blossissuez I had a white pegion but then he died ;(
# 19  @AskAnything_RK @Shafquat__Khan @17050a1 @somil_y @asadowaisi @PMOIndia Bro they won't understand 😂, you give them facts they will ignore it! It's like a game of chess against a pegion 🤡
# 20  @amanprabhakar_ hey Aman I found an injured pegion in my parking area and thought I could help it survive. Can you help me out here?? https://t.co/FNOdkXdXDd
# 21  I'm still mad and sad about something very stupid and I will probably still be for a long time because I'm absolutely spitefull and I can't even tell the people involved because I think I am in the wrong by being childish and egoist. Smh, fuck
# 22  @ParveenKaswan Pegion From Phone camera 😅 https://t.co/XoB1H8hjim
# 23  @Murky__Meg Her face says it all! Spitefull vindictive look that cant be hidden. Such a shame Harry couldnt see this streak in her.
# 24  @AstuteAilleacht "--- greater good?" He leaned closer to her and whispered: "I am Gellert Grindelwald."
# 25  Pegion Residency by Universal*_\n _Located at Tank Hill rd end, ahead of the stone quarry._\n _With a choice of 1 bedroom, 2bedroom and 3bedroom apartment_ \n _*Starting at 172m*_\n _Our representatives are here to help_ \n\nJulie - +256703335253\nDorah - +256783277052 https://t.co/PBGrLNFPfd
# 26  Please my people never compare @stonebwoyb  with @shattawalegh  sake dancehall is all about partoa and wale speaks pegion not partoa 🧐🧐🧐
# 27  Richard Nixon is our Gellert Grindelwald #comeymemo
# 28  I do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  Stupid bitch i wanna squish this and make a pegion sandwich https://t.co/lS2JI2xvFH
# 30  India has blamed  pegion for spying for Pakistan. Now they are blaming the infectious disease center for development anthrax like pathogen. The article says that sinopharm of china is carrying vaccine trials for coronavirus  on pakistan citizens while he ignored tests in UAE https://t.co/zjwJqQNszp
# 31  @AceMcWicked Qudditch is cancelled af though. But large amounts of beer is, as it so happens, intrinsic to the culture and history of Morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  #Democrats are shitty spitefull morons! They are truely evil vile human beings. After that donkey show today they should all be tossed out on their asses! P.S. Jerry Nadler is a fat fucking slob!
# 33  @Words_By_Aubrey Absolutely!! Nasty vile wicked spitefull individual.
# 34  #WhyIDontLikeTrump YESTERDAY AGBARR BESIDES THE DAY TRUMP SWORN IN, WAS SADDEST EVER. RACEIST AGBARR CHIEF ENABLER TO RACEIST TRUMP, ILL INFORMED NAZI TRUMP, BESIDES VIRUS WERE ALSO FIGHTING CORRUPT HATEFULL SPITEFULL DR DEATH HIMSELF TRUMP.
# 35  @oakridgeboys We have tickets for Aug. 7th 2020 Pegion Forge TN. Not going to happen is it😢? They still have everything still up on their we'd page
# 36  @Andaaz13 Yes, it sure is one. A Himalayan green pegion. Checked my Birds of India book before replying 😊
# 37  @KloeKitty This cruel thesis, a spitefull angel's litany,\nWill soon soar from the window of your destiny.
# 38  @varunvidyalink @AzharHS96 @GeneralBakshi #India is a country who makes its people fool with fake surgical strikes, propaganda videos, fake pictures, pegion  and locusts, in reality #IndianArmy always gets thrashed &amp; humiliated by #Pakistan and #China with online available proves 😁😁😁😁 @majorgauravarya @fawadchaudhry
# 39  @subhash_kak Even a pegion is introduced to a 2 yrs child as pegion n not as Kabootar. Cow as cow instead of gaay or gau. Instead of Tata we r teaching Bye. Instead of क्षमा we teach sorry. Instead of कृपया we teach please. But we will wait for clear opinion till all Points r cleared.
# 40  Stupid pegion app😞
# 41  @nickmangwana I would prefer the fist as compared to this mud pegion design
# 42  @RepHankJohnson ...is it appropriate to attack a witnessing front of the body,  while the witness appears before the body?...\n\nYOU'RE A FUCKING SPITEFULL HYPOCRITE FUCKTARD \n\nFUCK YOU DOUCHBAG
# 43  @Ratatosk4 Is this is this is what happens when hoomins become pegion fanciers?
# 44  J.K. Rowling reveals Gellert Grindelwald actually had cyan eyes, stringy hair, and a persistent personality.
# 45  @EdOznerol @BigBertieT @GOPLeader You won't play that game because you have no answers for it that's why. and he does have an infrastructure plan and a health plan and if Congress don't sign it, like I said it's because of the spitefull Democrats
# 46  Does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over. I will never buy anything from this company just because they are annoying. #becauseIdo #spitefull #letmewatchinpeace
# 47  Victoria crowned pigeon ⁣\n.⁣\n.⁣\n.⁣\n.⁣\n.⁣\n#pigeonforge #fancypigeon #birdlovers #instagood #pigeonlife #nature #merpatibandung #instagram #cute #pigeons #bird #pigeonsofinstagram #birdofinstagram #pigeonlove #pegion… https://t.co/npFO5Jn0y0
# 48  Sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking HOW did they came up with the name tho?
# 49  @DavidMw26334843 Trying to be  a white pegion  around black ones..how can we make the system work if someone  is taking 60mil bucks from the  already limbing sector ready to fall.
#
#    Sentiment
# 0   positive
# 1   neutral
# 2   positive
# 3   negative
# 4   negative
# 5   neutral
# 6   negative
# 7   negative
# 8   positive
# 9   positive
# 10  negative
# 11  neutral
# 12  neutral
# 13  neutral
# 14  positive
# 15  positive
# 16  neutral
# 17  neutral
# 18  neutral
# 19  negative
# 20  neutral
# 21  negative
# 22  neutral
# 23  negative
# 24  positive
# 25  neutral
# 26  neutral
# 27  neutral
# 28  negative
# 29  negative
# 30  negative
# 31  positive
# 32  negative
# 33  negative
# 34  negative
# 35  neutral
# 36  positive
# 37  negative
# 38  negative
# 39  negative
# 40  negative
# 41  neutral
# 42  negative
# 43  neutral
# 44  neutral
# 45  negative
# 46  negative
# 47  positive
# 48  neutral
# 49  positive

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29348 entries, 0 to 29347
# Data columns (total 5 columns):
# ID            29348 non-null int64
# Date- Time    29348 non-null object
# User_Name     29345 non-null object
# Tweet         29348 non-null object
# Sentiment     29348 non-null object
# dtypes: int64(1), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
#     The dataset contains attributes : Tweet , tweet id , data time , username & sentiment , out of these we only need
#     tweet and sentiment for our supervised machine learning classification algorithm

# %%
tweets= tweets[['Sentiment','Tweet']]
tweets.head(50)
# Out:
#    Sentiment  \
# 0   positive
# 1   neutral
# 2   positive
# 3   negative
# 4   negative
# 5   neutral
# 6   negative
# 7   negative
# 8   positive
# 9   positive
# 10  negative
# 11  neutral
# 12  neutral
# 13  neutral
# 14  positive
# 15  positive
# 16  neutral
# 17  neutral
# 18  neutral
# 19  negative
# 20  neutral
# 21  negative
# 22  neutral
# 23  negative
# 24  positive
# 25  neutral
# 26  neutral
# 27  neutral
# 28  negative
# 29  negative
# 30  negative
# 31  positive
# 32  negative
# 33  negative
# 34  negative
# 35  neutral
# 36  positive
# 37  negative
# 38  negative
# 39  negative
# 40  negative
# 41  neutral
# 42  negative
# 43  neutral
# 44  neutral
# 45  negative
# 46  negative
# 47  positive
# 48  neutral
# 49  positive
#
#                                                                                                                                                                                                                                                                                                                                 Tweet
# 0   i need to make my own SapceX, some people dont deserve to live here
# 1   Thre was mention of this earlier, the infraction on the views of the cosmos from the SapceX array and how astronomy would compensate. https://t.co/I5omeFq4SM
# 2   @bhab005 @KanganaTeam @kunalpande8 Sachine Tendulkar handle his account and but here kangana team handles her. That's the difference here. And if she is doing that what's funny. She has earned that right. Also Jo log khud nahi bolte h wo dusron se bulwate Hain. Wo khud bol rahi h to galat. Kya h.
# 3   Mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   @gareebscientist @GauravG91 @Chandel1402 @isro @SpaceX He I mean... Vaibhav....spacex is doing great work.. But its unfair to compare two.. No offense to sapcex but I will chose ISRO over spacex AnyDay....
# 5   someone get me the panda pegion nike sb
# 6   Piers Morgan, A Scum Media "Star" Showing His Spitefull Side. What a Pathetic Little Man. https://t.co/fKIRzd7aGE
# 7   Old PC game skyboxes emit such elegiac auras\njust look at like\nThe skybox from the Harry potter 2 qudditch area
# 8   "Fantastic Beasts: The Crimes of Grindelwald, Gellert Grindelwald plans to raise an army of wizards to rule over non-magical beings. In response, Newt Scamander's former professor, Albus Dumbledore, seeks his help to stop him."\n#FantasticBeastsTheCrimesOfGrindelwald https://t.co/KmVVV9z7FB
# 9   @Selinakyle981 @filmsbyzoe also Kit Harrigton is good in this movie. I don't care what anybody says.
# 10  @fighterpics His excellency pegion a tragic loss we wont forget about
# 11  @KyleKulinski You think it's not a problem!!? \nDamn what a pegion holed murrican....
# 12  Pegion https://t.co/sEMQkMukGO
# 13  J.K. Rowling reveals Gellert Grindelwald actually had aquamarine eyes, short hair, and a bossy personality.
# 14  I was most famous for my defeat of Gellert Grindelwald, the discovery of the twelve uses of Dragon's Blood, and my work on alchemy with Nicolas Flamel
# 15  #CBICrucialForSSR\n@adityathakekar \n@Arnab_goshwamii \n@iujjawaltrivedi \nADITYA THAKREY  WHY YOU ARE BLOCKING THE TWITTER ACCOUNT OF EVERYBODY WHO IS TWEETING YOU? BETA  WHY ARE YOU SO SCARED? AS AN YOUTH, COME OUT FROM YOUR PEGION WHOLE N DEMAND CBI PROBE FOR YOUR FRIEND SUSHANT.
# 16  i've read qudditch legend renjun, volleyball setter renjun, and baseball captain renjun but never basketball player jun 💔
# 17  @ParveenKaswan Pegion ... https://t.co/OS6Ou6FeoI
# 18  @blossissuez I had a white pegion but then he died ;(
# 19  @AskAnything_RK @Shafquat__Khan @17050a1 @somil_y @asadowaisi @PMOIndia Bro they won't understand 😂, you give them facts they will ignore it! It's like a game of chess against a pegion 🤡
# 20  @amanprabhakar_ hey Aman I found an injured pegion in my parking area and thought I could help it survive. Can you help me out here?? https://t.co/FNOdkXdXDd
# 21  I'm still mad and sad about something very stupid and I will probably still be for a long time because I'm absolutely spitefull and I can't even tell the people involved because I think I am in the wrong by being childish and egoist. Smh, fuck
# 22  @ParveenKaswan Pegion From Phone camera 😅 https://t.co/XoB1H8hjim
# 23  @Murky__Meg Her face says it all! Spitefull vindictive look that cant be hidden. Such a shame Harry couldnt see this streak in her.
# 24  @AstuteAilleacht "--- greater good?" He leaned closer to her and whispered: "I am Gellert Grindelwald."
# 25  Pegion Residency by Universal*_\n _Located at Tank Hill rd end, ahead of the stone quarry._\n _With a choice of 1 bedroom, 2bedroom and 3bedroom apartment_ \n _*Starting at 172m*_\n _Our representatives are here to help_ \n\nJulie - +256703335253\nDorah - +256783277052 https://t.co/PBGrLNFPfd
# 26  Please my people never compare @stonebwoyb  with @shattawalegh  sake dancehall is all about partoa and wale speaks pegion not partoa 🧐🧐🧐
# 27  Richard Nixon is our Gellert Grindelwald #comeymemo
# 28  I do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  Stupid bitch i wanna squish this and make a pegion sandwich https://t.co/lS2JI2xvFH
# 30  India has blamed  pegion for spying for Pakistan. Now they are blaming the infectious disease center for development anthrax like pathogen. The article says that sinopharm of china is carrying vaccine trials for coronavirus  on pakistan citizens while he ignored tests in UAE https://t.co/zjwJqQNszp
# 31  @AceMcWicked Qudditch is cancelled af though. But large amounts of beer is, as it so happens, intrinsic to the culture and history of Morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  #Democrats are shitty spitefull morons! They are truely evil vile human beings. After that donkey show today they should all be tossed out on their asses! P.S. Jerry Nadler is a fat fucking slob!
# 33  @Words_By_Aubrey Absolutely!! Nasty vile wicked spitefull individual.
# 34  #WhyIDontLikeTrump YESTERDAY AGBARR BESIDES THE DAY TRUMP SWORN IN, WAS SADDEST EVER. RACEIST AGBARR CHIEF ENABLER TO RACEIST TRUMP, ILL INFORMED NAZI TRUMP, BESIDES VIRUS WERE ALSO FIGHTING CORRUPT HATEFULL SPITEFULL DR DEATH HIMSELF TRUMP.
# 35  @oakridgeboys We have tickets for Aug. 7th 2020 Pegion Forge TN. Not going to happen is it😢? They still have everything still up on their we'd page
# 36  @Andaaz13 Yes, it sure is one. A Himalayan green pegion. Checked my Birds of India book before replying 😊
# 37  @KloeKitty This cruel thesis, a spitefull angel's litany,\nWill soon soar from the window of your destiny.
# 38  @varunvidyalink @AzharHS96 @GeneralBakshi #India is a country who makes its people fool with fake surgical strikes, propaganda videos, fake pictures, pegion  and locusts, in reality #IndianArmy always gets thrashed &amp; humiliated by #Pakistan and #China with online available proves 😁😁😁😁 @majorgauravarya @fawadchaudhry
# 39  @subhash_kak Even a pegion is introduced to a 2 yrs child as pegion n not as Kabootar. Cow as cow instead of gaay or gau. Instead of Tata we r teaching Bye. Instead of क्षमा we teach sorry. Instead of कृपया we teach please. But we will wait for clear opinion till all Points r cleared.
# 40  Stupid pegion app😞
# 41  @nickmangwana I would prefer the fist as compared to this mud pegion design
# 42  @RepHankJohnson ...is it appropriate to attack a witnessing front of the body,  while the witness appears before the body?...\n\nYOU'RE A FUCKING SPITEFULL HYPOCRITE FUCKTARD \n\nFUCK YOU DOUCHBAG
# 43  @Ratatosk4 Is this is this is what happens when hoomins become pegion fanciers?
# 44  J.K. Rowling reveals Gellert Grindelwald actually had cyan eyes, stringy hair, and a persistent personality.
# 45  @EdOznerol @BigBertieT @GOPLeader You won't play that game because you have no answers for it that's why. and he does have an infrastructure plan and a health plan and if Congress don't sign it, like I said it's because of the spitefull Democrats
# 46  Does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over. I will never buy anything from this company just because they are annoying. #becauseIdo #spitefull #letmewatchinpeace
# 47  Victoria crowned pigeon ⁣\n.⁣\n.⁣\n.⁣\n.⁣\n.⁣\n#pigeonforge #fancypigeon #birdlovers #instagood #pigeonlife #nature #merpatibandung #instagram #cute #pigeons #bird #pigeonsofinstagram #birdofinstagram #pigeonlove #pegion… https://t.co/npFO5Jn0y0
# 48  Sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking HOW did they came up with the name tho?
# 49  @DavidMw26334843 Trying to be  a white pegion  around black ones..how can we make the system work if someone  is taking 60mil bucks from the  already limbing sector ready to fall.

# %% [markdown]
#     As the sentiment is given in string format we need to convert them into numerical values which will serve as the
#     class labels for the supervised machine learning algorithm.

# %%
Sentiment = {'negative': 0,'positive': 1,'neutral' : 2}
tweets.Sentiment = [Sentiment[item] for item in tweets.Sentiment]
tweets.head(50)
# Out:
#     Sentiment  \
# 0   1
# 1   2
# 2   1
# 3   0
# 4   0
# 5   2
# 6   0
# 7   0
# 8   1
# 9   1
# 10  0
# 11  2
# 12  2
# 13  2
# 14  1
# 15  1
# 16  2
# 17  2
# 18  2
# 19  0
# 20  2
# 21  0
# 22  2
# 23  0
# 24  1
# 25  2
# 26  2
# 27  2
# 28  0
# 29  0
# 30  0
# 31  1
# 32  0
# 33  0
# 34  0
# 35  2
# 36  1
# 37  0
# 38  0
# 39  0
# 40  0
# 41  2
# 42  0
# 43  2
# 44  2
# 45  0
# 46  0
# 47  1
# 48  2
# 49  1
#
#                                                                                                                                                                                                                                                                                                                                 Tweet
# 0   i need to make my own SapceX, some people dont deserve to live here
# 1   Thre was mention of this earlier, the infraction on the views of the cosmos from the SapceX array and how astronomy would compensate. https://t.co/I5omeFq4SM
# 2   @bhab005 @KanganaTeam @kunalpande8 Sachine Tendulkar handle his account and but here kangana team handles her. That's the difference here. And if she is doing that what's funny. She has earned that right. Also Jo log khud nahi bolte h wo dusron se bulwate Hain. Wo khud bol rahi h to galat. Kya h.
# 3   Mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   @gareebscientist @GauravG91 @Chandel1402 @isro @SpaceX He I mean... Vaibhav....spacex is doing great work.. But its unfair to compare two.. No offense to sapcex but I will chose ISRO over spacex AnyDay....
# 5   someone get me the panda pegion nike sb
# 6   Piers Morgan, A Scum Media "Star" Showing His Spitefull Side. What a Pathetic Little Man. https://t.co/fKIRzd7aGE
# 7   Old PC game skyboxes emit such elegiac auras\njust look at like\nThe skybox from the Harry potter 2 qudditch area
# 8   "Fantastic Beasts: The Crimes of Grindelwald, Gellert Grindelwald plans to raise an army of wizards to rule over non-magical beings. In response, Newt Scamander's former professor, Albus Dumbledore, seeks his help to stop him."\n#FantasticBeastsTheCrimesOfGrindelwald https://t.co/KmVVV9z7FB
# 9   @Selinakyle981 @filmsbyzoe also Kit Harrigton is good in this movie. I don't care what anybody says.
# 10  @fighterpics His excellency pegion a tragic loss we wont forget about
# 11  @KyleKulinski You think it's not a problem!!? \nDamn what a pegion holed murrican....
# 12  Pegion https://t.co/sEMQkMukGO
# 13  J.K. Rowling reveals Gellert Grindelwald actually had aquamarine eyes, short hair, and a bossy personality.
# 14  I was most famous for my defeat of Gellert Grindelwald, the discovery of the twelve uses of Dragon's Blood, and my work on alchemy with Nicolas Flamel
# 15  #CBICrucialForSSR\n@adityathakekar \n@Arnab_goshwamii \n@iujjawaltrivedi \nADITYA THAKREY  WHY YOU ARE BLOCKING THE TWITTER ACCOUNT OF EVERYBODY WHO IS TWEETING YOU? BETA  WHY ARE YOU SO SCARED? AS AN YOUTH, COME OUT FROM YOUR PEGION WHOLE N DEMAND CBI PROBE FOR YOUR FRIEND SUSHANT.
# 16  i've read qudditch legend renjun, volleyball setter renjun, and baseball captain renjun but never basketball player jun 💔
# 17  @ParveenKaswan Pegion ... https://t.co/OS6Ou6FeoI
# 18  @blossissuez I had a white pegion but then he died ;(
# 19  @AskAnything_RK @Shafquat__Khan @17050a1 @somil_y @asadowaisi @PMOIndia Bro they won't understand 😂, you give them facts they will ignore it! It's like a game of chess against a pegion 🤡
# 20  @amanprabhakar_ hey Aman I found an injured pegion in my parking area and thought I could help it survive. Can you help me out here?? https://t.co/FNOdkXdXDd
# 21  I'm still mad and sad about something very stupid and I will probably still be for a long time because I'm absolutely spitefull and I can't even tell the people involved because I think I am in the wrong by being childish and egoist. Smh, fuck
# 22  @ParveenKaswan Pegion From Phone camera 😅 https://t.co/XoB1H8hjim
# 23  @Murky__Meg Her face says it all! Spitefull vindictive look that cant be hidden. Such a shame Harry couldnt see this streak in her.
# 24  @AstuteAilleacht "--- greater good?" He leaned closer to her and whispered: "I am Gellert Grindelwald."
# 25  Pegion Residency by Universal*_\n _Located at Tank Hill rd end, ahead of the stone quarry._\n _With a choice of 1 bedroom, 2bedroom and 3bedroom apartment_ \n _*Starting at 172m*_\n _Our representatives are here to help_ \n\nJulie - +256703335253\nDorah - +256783277052 https://t.co/PBGrLNFPfd
# 26  Please my people never compare @stonebwoyb  with @shattawalegh  sake dancehall is all about partoa and wale speaks pegion not partoa 🧐🧐🧐
# 27  Richard Nixon is our Gellert Grindelwald #comeymemo
# 28  I do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  Stupid bitch i wanna squish this and make a pegion sandwich https://t.co/lS2JI2xvFH
# 30  India has blamed  pegion for spying for Pakistan. Now they are blaming the infectious disease center for development anthrax like pathogen. The article says that sinopharm of china is carrying vaccine trials for coronavirus  on pakistan citizens while he ignored tests in UAE https://t.co/zjwJqQNszp
# 31  @AceMcWicked Qudditch is cancelled af though. But large amounts of beer is, as it so happens, intrinsic to the culture and history of Morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  #Democrats are shitty spitefull morons! They are truely evil vile human beings. After that donkey show today they should all be tossed out on their asses! P.S. Jerry Nadler is a fat fucking slob!
# 33  @Words_By_Aubrey Absolutely!! Nasty vile wicked spitefull individual.
# 34  #WhyIDontLikeTrump YESTERDAY AGBARR BESIDES THE DAY TRUMP SWORN IN, WAS SADDEST EVER. RACEIST AGBARR CHIEF ENABLER TO RACEIST TRUMP, ILL INFORMED NAZI TRUMP, BESIDES VIRUS WERE ALSO FIGHTING CORRUPT HATEFULL SPITEFULL DR DEATH HIMSELF TRUMP.
# 35  @oakridgeboys We have tickets for Aug. 7th 2020 Pegion Forge TN. Not going to happen is it😢? They still have everything still up on their we'd page
# 36  @Andaaz13 Yes, it sure is one. A Himalayan green pegion. Checked my Birds of India book before replying 😊
# 37  @KloeKitty This cruel thesis, a spitefull angel's litany,\nWill soon soar from the window of your destiny.
# 38  @varunvidyalink @AzharHS96 @GeneralBakshi #India is a country who makes its people fool with fake surgical strikes, propaganda videos, fake pictures, pegion  and locusts, in reality #IndianArmy always gets thrashed &amp; humiliated by #Pakistan and #China with online available proves 😁😁😁😁 @majorgauravarya @fawadchaudhry
# 39  @subhash_kak Even a pegion is introduced to a 2 yrs child as pegion n not as Kabootar. Cow as cow instead of gaay or gau. Instead of Tata we r teaching Bye. Instead of क्षमा we teach sorry. Instead of कृपया we teach please. But we will wait for clear opinion till all Points r cleared.
# 40  Stupid pegion app😞
# 41  @nickmangwana I would prefer the fist as compared to this mud pegion design
# 42  @RepHankJohnson ...is it appropriate to attack a witnessing front of the body,  while the witness appears before the body?...\n\nYOU'RE A FUCKING SPITEFULL HYPOCRITE FUCKTARD \n\nFUCK YOU DOUCHBAG
# 43  @Ratatosk4 Is this is this is what happens when hoomins become pegion fanciers?
# 44  J.K. Rowling reveals Gellert Grindelwald actually had cyan eyes, stringy hair, and a persistent personality.
# 45  @EdOznerol @BigBertieT @GOPLeader You won't play that game because you have no answers for it that's why. and he does have an infrastructure plan and a health plan and if Congress don't sign it, like I said it's because of the spitefull Democrats
# 46  Does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over. I will never buy anything from this company just because they are annoying. #becauseIdo #spitefull #letmewatchinpeace
# 47  Victoria crowned pigeon ⁣\n.⁣\n.⁣\n.⁣\n.⁣\n.⁣\n#pigeonforge #fancypigeon #birdlovers #instagood #pigeonlife #nature #merpatibandung #instagram #cute #pigeons #bird #pigeonsofinstagram #birdofinstagram #pigeonlove #pegion… https://t.co/npFO5Jn0y0
# 48  Sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking HOW did they came up with the name tho?
# 49  @DavidMw26334843 Trying to be  a white pegion  around black ones..how can we make the system work if someone  is taking 60mil bucks from the  already limbing sector ready to fall.

# %% [markdown]
# # Cleaning Data
#
#         From the tweets we need to remove:
#         1. mentions or usernames : @abcd
#         2. Hashtags : #happy --> happy
#         3. convert all tweets in Lowercase :
#                 this is done because upeercase and lower case charecters are treated as differnt as a result
#                 while converting a word in vector , same words may give different vectors if the casing of the letters
#                 in the words varies.
#         4. Remove extra white spaces
#         5. Remove numbers/digits
#         6. Remove Hyperlinks
#         7. Remove New Lines

# %% [markdown]
#         re.sub(r'@[A-za-z0-9]+','',text) :
#             r: tells python the text is raw text
#             @[A-za-z0-9]+ : any pattern starting with @ and followed by letterts or alphabet one or more.
#
#         'http?s:\/\/\S+' : remove http, '?s' means s may or may not be present folowwed by // till we
#                                get one or more white space denoted by'S+'

# %%
# create a function to clean text
def cleanTxt(text):
    text= re.sub(r'@[A-za-z0-9]+','',text) # remove mentions
    text= re.sub(r'#','',text) # remove # from text
    text= re.sub(r'http?s:\/\/\S+','',text) # remove Hyperlink
    text= re.sub(r'\n',' ',text) # remove new line
    text = re.sub(r'\d+','', text) # remove numbers
    
    # remove punctuations and convert characters to lower case
    text = "".join([char.lower() for char in text if char not in string.punctuation]) 
    # substitute multiple whitespace with single whitespace
    # Also, removes leading and trailing whitespaces
    text = re.sub('\s+', ' ', text).strip()
    
    return text

# %% [markdown]
# # Apply cleanTxt to our data

# %%
tweets['Tweet']= tweets['Tweet'].apply(cleanTxt)
tweets.head(50)
# Out:
#     Sentiment  \
# 0   1
# 1   2
# 2   1
# 3   0
# 4   0
# 5   2
# 6   0
# 7   0
# 8   1
# 9   1
# 10  0
# 11  2
# 12  2
# 13  2
# 14  1
# 15  1
# 16  2
# 17  2
# 18  2
# 19  0
# 20  2
# 21  0
# 22  2
# 23  0
# 24  1
# 25  2
# 26  2
# 27  2
# 28  0
# 29  0
# 30  0
# 31  1
# 32  0
# 33  0
# 34  0
# 35  2
# 36  1
# 37  0
# 38  0
# 39  0
# 40  0
# 41  2
# 42  0
# 43  2
# 44  2
# 45  0
# 46  0
# 47  1
# 48  2
# 49  1
#
#                                                                                                                                                                                                                                                                                   Tweet
# 0   i need to make my own sapcex some people dont deserve to live here
# 1   thre was mention of this earlier the infraction on the views of the cosmos from the sapcex array and how astronomy would compensate
# 2   sachine tendulkar handle his account and but here kangana team handles her thats the difference here and if she is doing that whats funny she has earned that right also jo log khud nahi bolte h wo dusron se bulwate hain wo khud bol rahi h to galat kya h
# 3   mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   he i mean vaibhavspacex is doing great work but its unfair to compare two no offense to sapcex but i will chose isro over spacex anyday
# 5   someone get me the panda pegion nike sb
# 6   piers morgan a scum media star showing his spitefull side what a pathetic little man
# 7   old pc game skyboxes emit such elegiac auras just look at like the skybox from the harry potter qudditch area
# 8   fantastic beasts the crimes of grindelwald gellert grindelwald plans to raise an army of wizards to rule over nonmagical beings in response newt scamanders former professor albus dumbledore seeks his help to stop him fantasticbeaststhecrimesofgrindelwald
# 9   also kit harrigton is good in this movie i dont care what anybody says
# 10  his excellency pegion a tragic loss we wont forget about
# 11  you think its not a problem damn what a pegion holed murrican
# 12  pegion
# 13  jk rowling reveals gellert grindelwald actually had aquamarine eyes short hair and a bossy personality
# 14  i was most famous for my defeat of gellert grindelwald the discovery of the twelve uses of dragons blood and my work on alchemy with nicolas flamel
# 15  cbicrucialforssr aditya thakrey why you are blocking the twitter account of everybody who is tweeting you beta why are you so scared as an youth come out from your pegion whole n demand cbi probe for your friend sushant
# 16  ive read qudditch legend renjun volleyball setter renjun and baseball captain renjun but never basketball player jun 💔
# 17  pegion
# 18  i had a white pegion but then he died
# 19  bro they wont understand 😂 you give them facts they will ignore it its like a game of chess against a pegion 🤡
# 20  hey aman i found an injured pegion in my parking area and thought i could help it survive can you help me out here
# 21  im still mad and sad about something very stupid and i will probably still be for a long time because im absolutely spitefull and i cant even tell the people involved because i think i am in the wrong by being childish and egoist smh fuck
# 22  pegion from phone camera 😅
# 23  her face says it all spitefull vindictive look that cant be hidden such a shame harry couldnt see this streak in her
# 24  greater good he leaned closer to her and whispered i am gellert grindelwald
# 25  pegion residency by universal located at tank hill rd end ahead of the stone quarry with a choice of bedroom bedroom and bedroom apartment starting at m our representatives are here to help julie dorah
# 26  please my people never compare with sake dancehall is all about partoa and wale speaks pegion not partoa 🧐🧐🧐
# 27  richard nixon is our gellert grindelwald comeymemo
# 28  i do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  stupid bitch i wanna squish this and make a pegion sandwich
# 30  india has blamed pegion for spying for pakistan now they are blaming the infectious disease center for development anthrax like pathogen the article says that sinopharm of china is carrying vaccine trials for coronavirus on pakistan citizens while he ignored tests in uae
# 31  qudditch is cancelled af though but large amounts of beer is as it so happens intrinsic to the culture and history of morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  democrats are shitty spitefull morons they are truely evil vile human beings after that donkey show today they should all be tossed out on their asses ps jerry nadler is a fat fucking slob
# 33  absolutely nasty vile wicked spitefull individual
# 34  whyidontliketrump yesterday agbarr besides the day trump sworn in was saddest ever raceist agbarr chief enabler to raceist trump ill informed nazi trump besides virus were also fighting corrupt hatefull spitefull dr death himself trump
# 35  we have tickets for aug th pegion forge tn not going to happen is it😢 they still have everything still up on their wed page
# 36  yes it sure is one a himalayan green pegion checked my birds of india book before replying 😊
# 37  this cruel thesis a spitefull angels litany will soon soar from the window of your destiny
# 38  india is a country who makes its people fool with fake surgical strikes propaganda videos fake pictures pegion and locusts in reality indianarmy always gets thrashed amp humiliated by pakistan and china with online available proves 😁😁😁😁
# 39  even a pegion is introduced to a yrs child as pegion n not as kabootar cow as cow instead of gaay or gau instead of tata we r teaching bye instead of क्षमा we teach sorry instead of कृपया we teach please but we will wait for clear opinion till all points r cleared
# 40  stupid pegion app😞
# 41  i would prefer the fist as compared to this mud pegion design
# 42  is it appropriate to attack a witnessing front of the body while the witness appears before the body youre a fucking spitefull hypocrite fucktard fuck you douchbag
# 43  is this is this is what happens when hoomins become pegion fanciers
# 44  jk rowling reveals gellert grindelwald actually had cyan eyes stringy hair and a persistent personality
# 45  you wont play that game because you have no answers for it thats why and he does have an infrastructure plan and a health plan and if congress dont sign it like i said its because of the spitefull democrats
# 46  does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over i will never buy anything from this company just because they are annoying becauseido spitefull letmewatchinpeace
# 47  victoria crowned pigeon ⁣ ⁣ ⁣ ⁣ ⁣ ⁣ pigeonforge fancypigeon birdlovers instagood pigeonlife nature merpatibandung instagram cute pigeons bird pigeonsofinstagram birdofinstagram pigeonlove pegion…
# 48  sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking how did they came up with the name tho
# 49  trying to be a white pegion around black oneshow can we make the system work if someone is taking mil bucks from the already limbing sector ready to fall

# %% [markdown]
# # The Tweets Still contains Emoji 😉
#
#     we can either remove them or replace them with equivalent text as sometimes these emoji do carry valuable
#     sentiments/information
#     example:
#     The food was 😍 : the emoji suggest the food was good (positive sentiment)
#     The food was 😑 : the emoji sugeest the food was bad or average (negative sentiment)
#     without emoji the text "The food was" seems to be Neutral
#
#     Therefore its better to retain the emoji by converting them to text in order to retain the actual sentiment
#
#     Note:
#     while replcaing emoji , emoji that are represented by multiple words ex: Happy_face or red-heart
#     so we also need to replace the "_", "-" with blank space.
#
#     delimiters=("", "") : by default delimeters are : , : i.e the text for emoji will place between two colons
#                           so replace the colon with empty string.

# %%
def convertEmoji(text):
    text = emoji.demojize(text, delimiters=("", ""))
    text = re.sub(r'_',' ', text) # replace underscore with single white space
    text = re.sub(r'-',' ', text) # replace '-' with single white space
    return text

# %% [markdown]
# # Apply emoji conversion to our data

# %%
tweets['Tweet']= tweets['Tweet'].apply(convertEmoji)
tweets.head(50)
# Out:
#     Sentiment  \
# 0   1
# 1   2
# 2   1
# 3   0
# 4   0
# 5   2
# 6   0
# 7   0
# 8   1
# 9   1
# 10  0
# 11  2
# 12  2
# 13  2
# 14  1
# 15  1
# 16  2
# 17  2
# 18  2
# 19  0
# 20  2
# 21  0
# 22  2
# 23  0
# 24  1
# 25  2
# 26  2
# 27  2
# 28  0
# 29  0
# 30  0
# 31  1
# 32  0
# 33  0
# 34  0
# 35  2
# 36  1
# 37  0
# 38  0
# 39  0
# 40  0
# 41  2
# 42  0
# 43  2
# 44  2
# 45  0
# 46  0
# 47  1
# 48  2
# 49  1
#
#                                                                                                                                                                                                                                                                                                                                                                Tweet
# 0   i need to make my own sapcex some people dont deserve to live here
# 1   thre was mention of this earlier the infraction on the views of the cosmos from the sapcex array and how astronomy would compensate
# 2   sachine tendulkar handle his account and but here kangana team handles her thats the difference here and if she is doing that whats funny she has earned that right also jo log khud nahi bolte h wo dusron se bulwate hain wo khud bol rahi h to galat kya h
# 3   mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   he i mean vaibhavspacex is doing great work but its unfair to compare two no offense to sapcex but i will chose isro over spacex anyday
# 5   someone get me the panda pegion nike sb
# 6   piers morgan a scum media star showing his spitefull side what a pathetic little man
# 7   old pc game skyboxes emit such elegiac auras just look at like the skybox from the harry potter qudditch area
# 8   fantastic beasts the crimes of grindelwald gellert grindelwald plans to raise an army of wizards to rule over nonmagical beings in response newt scamanders former professor albus dumbledore seeks his help to stop him fantasticbeaststhecrimesofgrindelwald
# 9   also kit harrigton is good in this movie i dont care what anybody says
# 10  his excellency pegion a tragic loss we wont forget about
# 11  you think its not a problem damn what a pegion holed murrican
# 12  pegion
# 13  jk rowling reveals gellert grindelwald actually had aquamarine eyes short hair and a bossy personality
# 14  i was most famous for my defeat of gellert grindelwald the discovery of the twelve uses of dragons blood and my work on alchemy with nicolas flamel
# 15  cbicrucialforssr aditya thakrey why you are blocking the twitter account of everybody who is tweeting you beta why are you so scared as an youth come out from your pegion whole n demand cbi probe for your friend sushant
# 16  ive read qudditch legend renjun volleyball setter renjun and baseball captain renjun but never basketball player jun broken heart
# 17  pegion
# 18  i had a white pegion but then he died
# 19  bro they wont understand face with tears of joy you give them facts they will ignore it its like a game of chess against a pegion clown face
# 20  hey aman i found an injured pegion in my parking area and thought i could help it survive can you help me out here
# 21  im still mad and sad about something very stupid and i will probably still be for a long time because im absolutely spitefull and i cant even tell the people involved because i think i am in the wrong by being childish and egoist smh fuck
# 22  pegion from phone camera grinning face with sweat
# 23  her face says it all spitefull vindictive look that cant be hidden such a shame harry couldnt see this streak in her
# 24  greater good he leaned closer to her and whispered i am gellert grindelwald
# 25  pegion residency by universal located at tank hill rd end ahead of the stone quarry with a choice of bedroom bedroom and bedroom apartment starting at m our representatives are here to help julie dorah
# 26  please my people never compare with sake dancehall is all about partoa and wale speaks pegion not partoa face with monocleface with monocleface with monocle
# 27  richard nixon is our gellert grindelwald comeymemo
# 28  i do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  stupid bitch i wanna squish this and make a pegion sandwich
# 30  india has blamed pegion for spying for pakistan now they are blaming the infectious disease center for development anthrax like pathogen the article says that sinopharm of china is carrying vaccine trials for coronavirus on pakistan citizens while he ignored tests in uae
# 31  qudditch is cancelled af though but large amounts of beer is as it so happens intrinsic to the culture and history of morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  democrats are shitty spitefull morons they are truely evil vile human beings after that donkey show today they should all be tossed out on their asses ps jerry nadler is a fat fucking slob
# 33  absolutely nasty vile wicked spitefull individual
# 34  whyidontliketrump yesterday agbarr besides the day trump sworn in was saddest ever raceist agbarr chief enabler to raceist trump ill informed nazi trump besides virus were also fighting corrupt hatefull spitefull dr death himself trump
# 35  we have tickets for aug th pegion forge tn not going to happen is itcrying face they still have everything still up on their wed page
# 36  yes it sure is one a himalayan green pegion checked my birds of india book before replying smiling face with smiling eyes
# 37  this cruel thesis a spitefull angels litany will soon soar from the window of your destiny
# 38  india is a country who makes its people fool with fake surgical strikes propaganda videos fake pictures pegion and locusts in reality indianarmy always gets thrashed amp humiliated by pakistan and china with online available proves beaming face with smiling eyesbeaming face with smiling eyesbeaming face with smiling eyesbeaming face with smiling eyes
# 39  even a pegion is introduced to a yrs child as pegion n not as kabootar cow as cow instead of gaay or gau instead of tata we r teaching bye instead of क्षमा we teach sorry instead of कृपया we teach please but we will wait for clear opinion till all points r cleared
# 40  stupid pegion appdisappointed face
# 41  i would prefer the fist as compared to this mud pegion design
# 42  is it appropriate to attack a witnessing front of the body while the witness appears before the body youre a fucking spitefull hypocrite fucktard fuck you douchbag
# 43  is this is this is what happens when hoomins become pegion fanciers
# 44  jk rowling reveals gellert grindelwald actually had cyan eyes stringy hair and a persistent personality
# 45  you wont play that game because you have no answers for it thats why and he does have an infrastructure plan and a health plan and if congress dont sign it like i said its because of the spitefull democrats
# 46  does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over i will never buy anything from this company just because they are annoying becauseido spitefull letmewatchinpeace
# 47  victoria crowned pigeon ⁣ ⁣ ⁣ ⁣ ⁣ ⁣ pigeonforge fancypigeon birdlovers instagood pigeonlife nature merpatibandung instagram cute pigeons bird pigeonsofinstagram birdofinstagram pigeonlove pegion…
# 48  sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking how did they came up with the name tho
# 49  trying to be a white pegion around black oneshow can we make the system work if someone is taking mil bucks from the already limbing sector ready to fall

# %% [markdown]
# # Now the Text free from mentions/Usernames , # , Hyperlinks and emojis are replaced with their meanings
#
#       also as the emoji are now converted to words , the sentiment of the tweet might change hence lets update
#       the sentiment accordingly

# %%
def get_tweet_sentiment(tweet): 
    
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(tweet)
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 1
    elif analysis.sentiment.polarity == 0: 
        return 2
    else: 
        return 0

# %%
tweets['Sentiment']= tweets['Tweet'].apply(get_tweet_sentiment)
tweets.head(50)
# Out:
#     Sentiment  \
# 0   1
# 1   2
# 2   1
# 3   0
# 4   0
# 5   2
# 6   0
# 7   0
# 8   1
# 9   1
# 10  0
# 11  2
# 12  2
# 13  2
# 14  1
# 15  1
# 16  0
# 17  2
# 18  2
# 19  1
# 20  2
# 21  0
# 22  2
# 23  0
# 24  1
# 25  2
# 26  2
# 27  2
# 28  0
# 29  0
# 30  0
# 31  1
# 32  0
# 33  0
# 34  0
# 35  2
# 36  1
# 37  0
# 38  0
# 39  0
# 40  0
# 41  2
# 42  0
# 43  2
# 44  2
# 45  0
# 46  0
# 47  1
# 48  2
# 49  1
#
#                                                                                                                                                                                                                                                                                                                                                                Tweet
# 0   i need to make my own sapcex some people dont deserve to live here
# 1   thre was mention of this earlier the infraction on the views of the cosmos from the sapcex array and how astronomy would compensate
# 2   sachine tendulkar handle his account and but here kangana team handles her thats the difference here and if she is doing that whats funny she has earned that right also jo log khud nahi bolte h wo dusron se bulwate hain wo khud bol rahi h to galat kya h
# 3   mainly stoltenberg scandanavian cowardly attacks oil pipe lines then running like weird inbred fish savages to underground bunkers i wont dive into it but that world is over and like nazis there being spitefull and abusive and fucking everything up because there dumb inbreds
# 4   he i mean vaibhavspacex is doing great work but its unfair to compare two no offense to sapcex but i will chose isro over spacex anyday
# 5   someone get me the panda pegion nike sb
# 6   piers morgan a scum media star showing his spitefull side what a pathetic little man
# 7   old pc game skyboxes emit such elegiac auras just look at like the skybox from the harry potter qudditch area
# 8   fantastic beasts the crimes of grindelwald gellert grindelwald plans to raise an army of wizards to rule over nonmagical beings in response newt scamanders former professor albus dumbledore seeks his help to stop him fantasticbeaststhecrimesofgrindelwald
# 9   also kit harrigton is good in this movie i dont care what anybody says
# 10  his excellency pegion a tragic loss we wont forget about
# 11  you think its not a problem damn what a pegion holed murrican
# 12  pegion
# 13  jk rowling reveals gellert grindelwald actually had aquamarine eyes short hair and a bossy personality
# 14  i was most famous for my defeat of gellert grindelwald the discovery of the twelve uses of dragons blood and my work on alchemy with nicolas flamel
# 15  cbicrucialforssr aditya thakrey why you are blocking the twitter account of everybody who is tweeting you beta why are you so scared as an youth come out from your pegion whole n demand cbi probe for your friend sushant
# 16  ive read qudditch legend renjun volleyball setter renjun and baseball captain renjun but never basketball player jun broken heart
# 17  pegion
# 18  i had a white pegion but then he died
# 19  bro they wont understand face with tears of joy you give them facts they will ignore it its like a game of chess against a pegion clown face
# 20  hey aman i found an injured pegion in my parking area and thought i could help it survive can you help me out here
# 21  im still mad and sad about something very stupid and i will probably still be for a long time because im absolutely spitefull and i cant even tell the people involved because i think i am in the wrong by being childish and egoist smh fuck
# 22  pegion from phone camera grinning face with sweat
# 23  her face says it all spitefull vindictive look that cant be hidden such a shame harry couldnt see this streak in her
# 24  greater good he leaned closer to her and whispered i am gellert grindelwald
# 25  pegion residency by universal located at tank hill rd end ahead of the stone quarry with a choice of bedroom bedroom and bedroom apartment starting at m our representatives are here to help julie dorah
# 26  please my people never compare with sake dancehall is all about partoa and wale speaks pegion not partoa face with monocleface with monocleface with monocle
# 27  richard nixon is our gellert grindelwald comeymemo
# 28  i do not like you and because there all sad pathetic cowardly sneeky jealous spitefull bk stabbing they think your like them your just trying to protect your self from what
# 29  stupid bitch i wanna squish this and make a pegion sandwich
# 30  india has blamed pegion for spying for pakistan now they are blaming the infectious disease center for development anthrax like pathogen the article says that sinopharm of china is carrying vaccine trials for coronavirus on pakistan citizens while he ignored tests in uae
# 31  qudditch is cancelled af though but large amounts of beer is as it so happens intrinsic to the culture and history of morris dancing which is a sport on account of it has teams and sometimes apparently fights
# 32  democrats are shitty spitefull morons they are truely evil vile human beings after that donkey show today they should all be tossed out on their asses ps jerry nadler is a fat fucking slob
# 33  absolutely nasty vile wicked spitefull individual
# 34  whyidontliketrump yesterday agbarr besides the day trump sworn in was saddest ever raceist agbarr chief enabler to raceist trump ill informed nazi trump besides virus were also fighting corrupt hatefull spitefull dr death himself trump
# 35  we have tickets for aug th pegion forge tn not going to happen is itcrying face they still have everything still up on their wed page
# 36  yes it sure is one a himalayan green pegion checked my birds of india book before replying smiling face with smiling eyes
# 37  this cruel thesis a spitefull angels litany will soon soar from the window of your destiny
# 38  india is a country who makes its people fool with fake surgical strikes propaganda videos fake pictures pegion and locusts in reality indianarmy always gets thrashed amp humiliated by pakistan and china with online available proves beaming face with smiling eyesbeaming face with smiling eyesbeaming face with smiling eyesbeaming face with smiling eyes
# 39  even a pegion is introduced to a yrs child as pegion n not as kabootar cow as cow instead of gaay or gau instead of tata we r teaching bye instead of क्षमा we teach sorry instead of कृपया we teach please but we will wait for clear opinion till all points r cleared
# 40  stupid pegion appdisappointed face
# 41  i would prefer the fist as compared to this mud pegion design
# 42  is it appropriate to attack a witnessing front of the body while the witness appears before the body youre a fucking spitefull hypocrite fucktard fuck you douchbag
# 43  is this is this is what happens when hoomins become pegion fanciers
# 44  jk rowling reveals gellert grindelwald actually had cyan eyes stringy hair and a persistent personality
# 45  you wont play that game because you have no answers for it thats why and he does have an infrastructure plan and a health plan and if congress dont sign it like i said its because of the spitefull democrats
# 46  does anyone else think to themselves when they are watching a video and the same ad keeps popping up over and over i will never buy anything from this company just because they are annoying becauseido spitefull letmewatchinpeace
# 47  victoria crowned pigeon ⁣ ⁣ ⁣ ⁣ ⁣ ⁣ pigeonforge fancypigeon birdlovers instagood pigeonlife nature merpatibandung instagram cute pigeons bird pigeonsofinstagram birdofinstagram pigeonlove pegion…
# 48  sir is teaching about pegion hole and pumping lemma which as supposed to be imp principles but my brain keeps asking how did they came up with the name tho
# 49  trying to be a white pegion around black oneshow can we make the system work if someone is taking mil bucks from the already limbing sector ready to fall

# %% [markdown]
# # Now to Normailze the text , convert the text into tokens and perfrom stemming
#
#     Tokenizing: Turning the tweets into tokens. Tokens are words separated by spaces in a text.
#
#     Normalization: Normalization generally refers to a series of related tasks meant to put all text on the same level.
#                    Converting text to lower case, removing special characters, and removing stopwords will remove basic
#                    inconsistencies. Normalization improves text matching.
#
#                    we have already done majority of normalization ,only stopwords removal remians.
#
#      Stopword removal: Some words do not contribute much to the machine learning model, so it's good to remove them.
#
#      Stemming: Eliminating affixes (circumfixes, suffixes, prefixes, infixes) from a word in order to obtain a word stem.
#                Porter Stemmer is the most widely used technique because it is very fast.
#                Generally, stemming chops off end of the word, and mostly it works fine.
#                Example: Working -> Work
#
#      Lemmatization: The goal is same as with stemming, but stemming a word sometimes loses the actual meaning of the word.
#                     Lemmatization usually refers to doing things properly using vocabulary and morphological analysis of
#                     words. It returns the base or dictionary form of a word, also known as the lemma .
#                 Example: Better -> Good.
#
#       Here i am going to use lemmatization
#
#       syntax .lemmatize(word, pos='a'):
#               pos : part of speech tag , defualt : n (Noun)
#               pos = 'a' : adjective
#               example:
#               lemmatize('better',pos='a')==> good

# %%
def Tokenization(tweet):
    
    #convert to tokens and filter out stopwords
    stop_words = set(stopwords.words('english'))
    tweet_tokens = word_tokenize(tweet) 
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in filtered_words]
    
    return " ".join(lemma_words)

# %% [markdown]
# # Apply Tokenization to the Tweets

# %%
tweets['Tweet_Tokenized']= tweets['Tweet'].apply(Tokenization)
tweets.tail(200)
# Out:
#        Sentiment  \
# 29148  1
# 29149  0
# 29150  2
# 29151  2
# 29152  1
# 29153  1
# 29154  2
# 29155  2
# 29156  2
# 29157  2
# 29158  2
# 29159  2
# 29160  2
# 29161  1
# 29162  1
# 29163  2
# 29164  2
# 29165  0
# 29166  2
# 29167  1
# 29168  1
# 29169  1
# 29170  1
# 29171  1
# 29172  1
# 29173  1
# 29174  0
# 29175  2
# 29176  2
# 29177  1
# ...   ..
# 29318  0
# 29319  2
# 29320  2
# 29321  1
# 29322  2
# 29323  0
# 29324  2
# 29325  0
# 29326  2
# 29327  2
# 29328  1
# 29329  2
# 29330  2
# 29331  2
# 29332  2
# 29333  1
# 29334  0
# 29335  0
# 29336  2
# 29337  1
# 29338  2
# 29339  0
# 29340  1
# 29341  1
# 29342  0
# 29343  2
# 29344  0
# 29345  2
# 29346  2
# 29347  0
#
#                                                                                                                                                                                                                                                                               Tweet  \
# 29148  chelsea vs rennes live stream free tv channel kickoff time and team news for champions league group game tonight
# 29149  dow rallies points amid tight election race tech rally pushes nasdaq up
# 29150  what human rights are sacrificed under donald trump
# 29151  well its been years and im still iffy about donald trump
# 29152  joe biden chacha right now elections
# 29153  good project thumbs up btf cryptocurrencies bitcoin defi hodl
# 29154  stop ignoring putins hackers
# 29155  donald trump will never concede
# 29156  cry me a river meet the boss man joe biden
# 29157  i wrote about the role tech companies and news outlets could play in helping him scam his way to an illegitimate second term
# 29158  the presidential election reportedly had the highest voter turnout rate in years thank you all for doing your civic duty and making your voice heard your voice matters
# 29159  come on donald trump
# 29160  donald trump hasnt ‘already won’ the election via
# 29161  joe biden has received more votes than any candidate in us history stop suggesting he isn’t popular enough we could’ve had klobuchar we could’ve had harris we could’ve had bernie we could’ve had warren joe brought people out in droves votersuppression
# 29162  us election results live updates biden reaches mark in leads wins as counting resumes
# 29163  someoneeatingpopcorngif
# 29164  everyone who loves pakistan do tweet and support him is claiming that he can manufacture bitcoin in k usd and govt can sell it at k usd then why r u not listening to him imrankhanmeetwaqarzaka cryptokolegalkaro cryptokolegalkaro
# 29165  cnbc postal service data shows poor mailin ballot delivery rate in key swing states via
# 29166  the politics of the usa amp income joe biden won households with up to k households by k households by trump won k households by
# 29167  i don’t know what it will be but the digital money is coming fast maybe bitcoin
# 29168  baby trump wants the vote counting to stop because he thinks he’s already won and now he’s going to stomp his feet and break his rattle and bring in the supreme court the nightmare continues
# 29169  us election live results – will donald trump win as he leads pennsylvania – latest predictions and maps
# 29170  i felt really good and it was amazing all day all thanks to you all bitcoin bitcoincash
# 29171  similarity the more explicit “let me fix america after i fcked it all up” probably wouldn’t have worked for trump either
# 29172  it’s almost over — or is it time for a election special edition of asiain join editors amp make sense of latest and what really happened on electionnight more on
# 29173  the election is close because has made a concerted effort to steal it and he has been partially successful but joe biden is winning despite trumps efforts to undermine our democracy
# 29174  google election results on the results page everything is broken down house senate and various ballot measures
# 29175  jib uselection update results as trump battles joebiden
# 29176  donald trump anime character
# 29177  istanbul basaksehir vs man utd live stream free tv channel teams as martial plays – champions league latest updates
# ...                                                                                                                    ...
# 29318  but gods not running for presidency they got joe biden and this orange moron
# 29319  hey joe biden let’s twin lh
# 29320  indiawitharnab arnab goswami is facing this situation because of raising the voice against uddhav and sonia gandhilowest level of politics
# 29321  joe biden has gotten more votes than president obama in still more votes to be counted
# 29322  trump’s am tirade against democracy was what he planned all along
# 29323  yes i looked at joe biden and said to myself i want that man to run my country are you people serious i do believe this election is set the polls all of it they set it up for the steal and theyre getting away with it as ususal am i the only one that sees biden is evil
# 29324  us election – fox news coverage
# 29325  sign of the times we are unbeaten in the champions league and you’re playing dundalkloudly crying face
# 29326  there you go
# 29327  joe biden issues statement as he pulls ahead via
# 29328  honestly i cant see that stance being any different than how mnuchin trump feel about bitcoin theyre not fans of it today
# 29329  and so the lawsuits begin the post office did not do a ballot sweep in states as ordered by a federal judge potentially leaving thousands of ballots undelivered in time
# 29330  let’s try without danish keyboard bbc article debunking trumps bullshit
# 29331  in a nation that prides itself as a democratic beacon for the world why does want to stop counting votes every voice matters in our society – this election isn’t over until we counteveryvote everyvotecounts
# 29332  waqar zaka is claiming that he can manufacture bitcoin in k usd and govt can sell it at k usd then why you are not listening to him imrankhanmeetwaqarzaka cryptokolegalkaro
# 29333  us election results live updates biden reaches mark in leads wins as counting resumes
# 29334  you’re either all in or arent in at all so yes all black lives matter
# 29335  the election’s troubling message even if trump loses america’s political civil war isn’t over – mother jones
# 29336  in the last hour cdai cdai has grown crypto bitcoin
# 29337  keeps on giving a a dangerous corona virus mutation… b …in minks… c …leads to the killing of millions of these animals… d…in denmark alone maybe farming millions of mammals for human consumption and clothing isn’t such a great idea after all
# 29338  me in october vs me after four years of trump administration election night
# 29339  georgia still has at least votes left to count secretary of state says too close to call
# 29340  urgent ayone who was told use sharpies get in touch w he needs to hear from you call him now watch s broadcast radio election too close to call legal battle begins
# 29341  praying for arnab goswami to be safe amp sound praying for republic tv staff praying for freedom of speech praying for justice indiawitharnab glowing starglowing starglowing star
# 29342  dont be fooled the delays in the us election result mean our system is working lawrence douglas
# 29343  bjp leader ram kadam to meet the maharashtra governor at am tomorrow to discuss the treatment meted out to arnab goswami
# 29344  gained one here black lives matter poc lives matter
# 29345  baat achhi hai but bjp needs to ensure his safety and wellbeing congress minister has already cleared that one team is formed only to harass arnab goswami
# 29346  mohamed salah rates liverpools champions league chances as rio ferdinand backs reds
# 29347  people used to think arnab was a spokesman of the bjp well people were wrong bjp is the spokesperson of arnab goswami
#
#                                                                                                                                                                                 Tweet_Tokenized
# 29148  chelsea vs rennes live stream free tv channel kickoff time team news champions league group game tonight
# 29149  dow rallies points amid tight election race tech rally pushes nasdaq
# 29150  human rights sacrificed donald trump
# 29151  well years im still iffy donald trump
# 29152  joe biden chacha right elections
# 29153  good project thumbs btf cryptocurrencies bitcoin defi hodl
# 29154  stop ignoring putins hackers
# 29155  donald trump never concede
# 29156  cry river meet boss man joe biden
# 29157  wrote role tech companies news outlets could play helping scam way illegitimate second term
# 29158  presidential election reportedly high voter turnout rate years thank civic duty making voice heard voice matters
# 29159  come donald trump
# 29160  donald trump hasnt ‘ already ’ election via
# 29161  joe biden received votes candidate us history stop suggesting ’ popular enough could ’ klobuchar could ’ harris could ’ bernie could ’ warren joe brought people droves votersuppression
# 29162  us election results live updates biden reaches mark leads wins counting resumes
# 29163  someoneeatingpopcorngif
# 29164  everyone loves pakistan tweet support claiming manufacture bitcoin k usd govt sell k usd r u listening imrankhanmeetwaqarzaka cryptokolegalkaro cryptokolegalkaro
# 29165  cnbc postal service data shows poor mailin ballot delivery rate key swing states via
# 29166  politics usa amp income joe biden households k households k households trump k households
# 29167  ’ know digital money coming fast maybe bitcoin
# 29168  baby trump wants vote counting stop thinks ’ already ’ going stomp feet break rattle bring supreme court nightmare continues
# 29169  us election live results – donald trump win leads pennsylvania – late predictions maps
# 29170  felt really good amazing day thanks bitcoin bitcoincash
# 29171  similarity explicit “ let fix america fcked ” probably ’ worked trump either
# 29172  ’ almost — time election special edition asiain join editors amp make sense late really happened electionnight
# 29173  election close made concerted effort steal partially successful joe biden winning despite trumps efforts undermine democracy
# 29174  google election results results page everything broken house senate various ballot measures
# 29175  jib uselection update results trump battles joebiden
# 29176  donald trump anime character
# 29177  istanbul basaksehir vs man utd live stream free tv channel teams martial plays – champions league late updates
# ...                                                                                                               ...
# 29318  gods running presidency got joe biden orange moron
# 29319  hey joe biden let ’ twin lh
# 29320  indiawitharnab arnab goswami facing situation raising voice uddhav sonia gandhilowest level politics
# 29321  joe biden gotten votes president obama still votes counted
# 29322  trump ’ tirade democracy planned along
# 29323  yes looked joe biden said want man run country people serious believe election set polls set steal theyre getting away ususal one sees biden evil
# 29324  us election – fox news coverage
# 29325  sign times unbeaten champions league ’ playing dundalkloudly crying face
# 29326  go
# 29327  joe biden issues statement pulls ahead via
# 29328  honestly cant see stance different mnuchin trump feel bitcoin theyre fans today
# 29329  lawsuits begin post office ballot sweep states ordered federal judge potentially leaving thousands ballots undelivered time
# 29330  let ’ try without danish keyboard bbc article debunking trumps bullshit
# 29331  nation prides democratic beacon world want stop counting votes every voice matters society – election ’ counteveryvote everyvotecounts
# 29332  waqar zaka claiming manufacture bitcoin k usd govt sell k usd listening imrankhanmeetwaqarzaka cryptokolegalkaro
# 29333  us election results live updates biden reaches mark leads wins counting resumes
# 29334  ’ either arent yes black lives matter
# 29335  election ’ troubling message even trump loses america ’ political civil war ’ – mother jones
# 29336  last hour cdai cdai grown crypto bitcoin
# 29337  keeps giving dangerous corona virus mutation… b …in minks… c …leads killing millions animals… d…in denmark alone maybe farming millions mammals human consumption clothing ’ great idea
# 29338  october vs four years trump administration election night
# 29339  georgia still least votes left count secretary state says close call
# 29340  urgent ayone told use sharpies get touch w needs hear call watch broadcast radio election close call legal battle begins
# 29341  praying arnab goswami safe amp sound praying republic tv staff praying freedom speech praying justice indiawitharnab glowing starglowing starglowing star
# 29342  dont fooled delays us election result mean system working lawrence douglas
# 29343  bjp leader ram kadam meet maharashtra governor tomorrow discuss treatment meted arnab goswami
# 29344  gained one black lives matter poc lives matter
# 29345  baat achhi hai bjp needs ensure safety wellbeing congress minister already cleared one team formed harass arnab goswami
# 29346  mohamed salah rates liverpools champions league chances rio ferdinand backs reds
# 29347  people used think arnab spokesman bjp well people wrong bjp spokesperson arnab goswami
#
# [200 rows x 3 columns]

# %%
tweets_array = tweets['Tweet_Tokenized'].values
tweets_array
# Out:
# array(['need make sapcex people dont deserve live',
#        'thre mention early infraction views cosmos sapcex array astronomy would compensate',
#        'sachine tendulkar handle account kangana team handles thats difference whats funny earned right also jo log khud nahi bolte h wo dusron se bulwate hain wo khud bol rahi h galat kya h',
#        ...,
#        'baat achhi hai bjp needs ensure safety wellbeing congress minister already cleared one team formed harass arnab goswami',
#        'mohamed salah rates liverpools champions league chances rio ferdinand backs reds',
#        'people used think arnab spokesman bjp well people wrong bjp spokesperson arnab goswami'],
#       dtype=object)

# %%
tweets_label =tweets['Sentiment'].values
tweets_label
# Out:
# array([1, 2, 1, ..., 2, 2, 0], dtype=int64)

# %% [markdown]
#     Now all we have a single array of tweets and each tweet serves as an unique element of the array.
#     However to convert tweets into vectors we need each word in a tweets as a seperate element or token.
#     hence applying Word_Tokenizer on the elements of your tweet array to get the required result.

# %%
Tokenized_Tweet = [word_tokenize(tweet) for tweet in tweets_array]
Tokenized_Tweet[0:5]
# Out:
# [['need', 'make', 'sapcex', 'people', 'dont', 'deserve', 'live'],
#  ['thre',
#   'mention',
#   'early',
#   'infraction',
#   'views',
#   'cosmos',
#   'sapcex',
#   'array',
#   'astronomy',
#   'would',
#   'compensate'],
#  ['sachine',
#   'tendulkar',
#   'handle',
#   'account',
#   'kangana',
#   'team',
#   'handles',
#   'thats',
#   'difference',
#   'whats',
#   'funny',
#   'earned',
#   'right',
#   'also',
#   'jo',
#   'log',
#   'khud',
#   'nahi',
#   'bolte',
#   'h',
#   'wo',
#   'dusron',
#   'se',
#   'bulwate',
#   'hain',
#   'wo',
#   'khud',
#   'bol',
#   'rahi',
#   'h',
#   'galat',
#   'kya',
#   'h'],
#  ['mainly',
#   'stoltenberg',
#   'scandanavian',
#   'cowardly',
#   'attacks',
#   'oil',
#   'pipe',
#   'lines',
#   'running',
#   'like',
#   'weird',
#   'inbred',
#   'fish',
#   'savages',
#   'underground',
#   'bunkers',
#   'wont',
#   'dive',
#   'world',
#   'like',
#   'nazis',
#   'spitefull',
#   'abusive',
#   'fucking',
#   'everything',
#   'dumb',
#   'inbreds'],
#  ['mean',
#   'vaibhavspacex',
#   'great',
#   'work',
#   'unfair',
#   'compare',
#   'two',
#   'offense',
#   'sapcex',
#   'chose',
#   'isro',
#   'spacex',
#   'anyday']]

# %% [markdown]
# # Convert Tweets into vectors:

# %% [markdown]
# # what is word embeddins , CBow And Skip-gram ?
#
#     ref : https://towardsdatascience.com/introduction-to-word-embedding-and-word2vec-652d0c2060fa
#
#     Word embeddings are vector representations of a particular word.
#     Word embedding is one of the most popular representation of document vocabulary.
#     It is capable of capturing context of a word in a document, semantic and syntactic similarity,
#     relation with other words, etc.
#
#     The objective is to have words with similar context occupy close spatial positions.
#     Mathematically, the cosine of the angle between such Word vectors should be close to 1, i.e. angle close to 0.
#
#     Word embedding using word2vec can be obtained using two methods (both involving Neural Networks)
#     Skip Gram and Common Bag Of Words (CBOW)
#
#     CBOW Model: This method takes the context of each words/vectors of V dimension as the input and tries to predict a word
#     corresponding to the context of V dimension.
#     ex: The sentence = Have a great day!
#         input/context words : have , a , great
#         output/target word : day
#
# ![](Cbow.png)
#
#     Skip- Gram : For each context words/vector of Dimension V we give as an input , we get c(window size) T
#     arget words of dimension V.
#      ex: The sentence = Have a great day!
#          input/context word : great
#          output/target words : have , a , day
#
# ![](skipgram.png)

# %% [markdown]
# # Build Word2Vec Model
#
#     parameter sg = 0 (default) means we are using Cbow
#               sg = 1 , means we are using Skip grams
#               size : the size of the vector we want
#               sentences : the tweets we want to convert into indiviual vectors
#               window : the number of adjacent neighbours to consider while using the Word2Vec Model.
#               Min_count : the minimum frequency of a word in the all the sentences for the Model to consider and
#                           include it in the vocabulary.
#                           ex : if min_count = 5
#                                the word 'rain' appears less than 5 times in all tweets ,
#                                'rain' wont be included in the vocabulary

# %%
Encoding_dim= 225  # size of vector we are converting each word token into.
model_cbow = Word2Vec(sentences=Tokenized_Tweet,window=5,min_count=5,size=Encoding_dim)
model_sg = Word2Vec(sentences=Tokenized_Tweet,window=5,min_count=5,size=Encoding_dim,sg=1)

# %% [markdown]
# # Train Word2Vec Models

# %%
model_cbow.train(Tokenized_Tweet, total_examples= len(Tokenized_Tweet),epochs=50)
# Out:
# (16331387, 19706300)

# %%
model_sg.train(Tokenized_Tweet, total_examples= len(Tokenized_Tweet),epochs=50)
# Out:
# (16330532, 19706300)

# %% [markdown]
# # Checking the number of Words we have in the created vocabulary
#
#     The number of unique words our word2vec model has identified and converted into vectors of length 225.

# %%
words_cbow=list(model_cbow.wv.vocab)
len(words_cbow)
# Out:
# 9197

# %%
words_sg=list(model_sg.wv.vocab)
len(words_sg)
# Out:
# 9197

# %% [markdown]
# # Test Models using similarity method

# %%
word = 'machine'
model_cbow.wv.most_similar(word,topn = 20)
# Out:
# [('learning', 0.5979888439178467),
#  ('python', 0.5182476043701172),
#  ('ai', 0.5143947005271912),
#  ('artificialintelligence', 0.4970901608467102),
#  ('machinelearning', 0.4919191896915436),
#  ('tensorflow', 0.4833938777446747),
#  ('deeplearning', 0.4790056049823761),
#  ('segmentation', 0.4789063632488251),
#  ('datascience', 0.47679877281188965),
#  ('developer', 0.4588560163974762),
#  ('javascript', 0.44089189171791077),
#  ('daysofcode', 0.42767134308815),
#  ('startup', 0.41915491223335266),
#  ('physics', 0.4171716570854187),
#  ('dl', 0.4166650176048279),
#  ('devices', 0.4152623414993286),
#  ('pytorch', 0.4149036705493927),
#  ('programming', 0.41370922327041626),
#  ('deep', 0.4125607907772064),
#  ('writingcommunity', 0.4083246886730194)]

# %%
word = 'artificial'
model_sg.wv.most_similar(word,topn = 20)
# Out:
# [('intelligence', 0.9130021333694458),
#  ('artificialintelligence', 0.5045976638793945),
#  ('mimics', 0.48775288462638855),
#  ('ai', 0.46392014622688293),
#  ('intoainews', 0.4468849003314972),
#  ('pharma', 0.4454767107963562),
#  ('fintech', 0.44431427121162415),
#  ('predicting', 0.4250364601612091),
#  ('daysofcode', 0.42240431904792786),
#  ('dl', 0.4208865761756897),
#  ('renaissance', 0.4144133925437927),
#  ('segmentation', 0.4142898917198181),
#  ('coding', 0.3954581320285797),
#  ('blockchain', 0.3928234577178955),
#  ('pytorch', 0.3926376402378082),
#  ('python', 0.39255058765411377),
#  ('bigdata', 0.3885931372642517),
#  ('neuralnetwork', 0.38473138213157654),
#  ('construct', 0.38199901580810547),
#  ('applied', 0.38050225377082825)]

# %% [markdown]
# # after evaluation of CBoW nd Skip Gram
#
#     i decided to continue with CBoW

# %% [markdown]
# # Preparing Vectors of Tweets for our classifier
#
#     Since our data contains tweets and not just words, we need to use the word vectors from word2vec model to create
#     vector representation for an entire tweet.
#     so to create a vector representing an entire tweet, we simply take mean of all the word vectors present in the tweet.
#     The length of the resultant vector will be the same( i.e. Encoding_dim)
#     The process is repeated for all the tweets in our data in order to obtain their corressponding vectors.

# %%
len(Tokenized_Tweet) # no of tokenized tweets
# Out:
# 29348

# %% [markdown]
# # lets see how the tweets looks after being converted into list of tokens

# %%
print(Tokenized_Tweet[0]) # view the tweet token of the tweet at index 0
print(Tokenized_Tweet[1]) # view the tweet token of the tweet at index 1
# Out:
# ['need', 'make', 'sapcex', 'people', 'dont', 'deserve', 'live']
# ['thre', 'mention', 'early', 'infraction', 'views', 'cosmos', 'sapcex', 'array', 'astronomy', 'would', 'compensate']

# %%
model_cbow.wv['sad']  # vector representation of a token or word in a tweet
# Out:
# array([ 1.004338  ,  0.27884057, -0.7056386 , -0.40404215,  1.4185158 ,
#        -0.39843926, -0.6184998 ,  0.41405445, -0.76336545,  0.08719177,
#        -0.8919954 , -0.74856025, -0.4799165 ,  0.3148121 ,  1.6419113 ,
#        -0.93059456, -0.35182962,  1.391968  , -2.2512245 , -0.6731917 ,
#        -0.6545812 ,  0.5670674 , -0.10561126, -1.6407723 , -0.18270741,
#        -0.3293092 , -0.282453  , -0.7575173 ,  0.60597396,  0.36679223,
#        -2.1617227 , -0.14040291,  0.30850452,  0.1724599 , -0.01348394,
#        -0.2243429 ,  0.07505868, -1.6545972 , -0.9568476 , -0.8250819 ,
#         1.3654121 ,  1.5311387 ,  0.26129645, -0.16224007,  1.8667996 ,
#        -0.45713726, -1.9338038 ,  0.34289917, -1.1465211 , -0.05848906,
#        -0.6770549 ,  1.3466448 ,  0.07787258, -0.14971097,  0.03256267,
#        -0.35036758,  2.1227624 ,  0.30728367,  1.5211561 , -0.11391378,
#         1.3703771 ,  0.04276436, -0.77282155, -0.1379203 ,  0.14210282,
#         2.5335798 ,  0.70119375,  0.6689275 , -0.94045234, -0.6944445 ,
#         0.1033296 , -1.1683    , -0.54952806,  0.8920085 , -1.020603  ,
#        -1.418232  , -1.1018566 ,  0.33552104, -0.3431409 , -0.6408996 ,
#        -0.38552672,  0.2797517 ,  1.2465436 , -0.23580976,  0.8383648 ,
#        -0.8078677 , -0.56262344,  0.04045096,  1.3432573 , -0.21112372,
#        -0.8964235 , -0.6005155 ,  1.0029845 , -0.933657  ,  0.04767732,
#        -0.25453654, -0.08699593, -0.87431264,  1.9685836 ,  0.70969784,
#        -1.2278593 ,  1.0782503 , -1.0563266 ,  0.16538681,  0.12710494,
#         1.1601647 ,  1.9164472 ,  1.4606737 ,  1.3503994 ,  0.7984985 ,
#         0.13973707,  0.9132552 ,  0.06524172, -0.8992056 ,  1.6504493 ,
#         1.1118213 , -0.28199413,  1.8514972 ,  1.6386418 ,  0.40904585,
#        -1.5792674 , -0.647445  ,  2.1928587 ,  0.7421981 ,  0.07629742,
#         0.9639815 ,  0.5258489 ,  0.5047655 ,  0.29332936,  0.8988855 ,
#         0.35739446,  0.15442276,  0.33375695, -0.07367642,  1.2952131 ,
#        -1.1994871 ,  0.5848919 , -0.51739556,  1.7028594 , -0.49272418,
#        -0.13300078,  1.9596989 , -1.4675051 , -0.46074247,  1.103086  ,
#         1.9152532 ,  0.02698892,  0.3833622 , -0.00733014, -0.25781572,
#        -1.3881229 , -0.01302965, -0.07540845,  1.4100382 ,  1.7036464 ,
#         0.0342814 ,  0.94575423,  1.174759  , -0.16540807,  0.02992557,
#        -1.2127422 ,  0.48126858, -0.43725607,  0.93569654, -0.49303257,
#         0.28628024,  0.36952484,  0.02546434,  0.13224868, -0.01047521,
#        -0.28943187, -0.75256765,  0.17046206,  0.8425376 ,  0.39041355,
#         0.25503436, -1.5913029 ,  1.5899047 ,  0.13665946, -1.6726484 ,
#         1.5698129 , -0.6889099 , -0.7491931 ,  1.2774488 ,  1.2322491 ,
#        -0.60651547, -0.17878716,  0.79625154, -0.16074456,  1.3301151 ,
#         0.7970804 ,  0.9579749 , -0.56232035,  1.8141766 , -1.2575436 ,
#        -0.24681221, -0.24603783,  0.65228045, -0.29008356, -0.79387504,
#        -1.9271753 ,  0.41025102,  0.24797131, -1.4399217 , -0.8775905 ,
#         0.80181813, -1.0539674 , -0.6139888 ,  0.64068776, -1.5053198 ,
#        -0.41228113, -1.3240054 ,  0.8553897 ,  2.0758104 , -0.6585105 ,
#         0.57917684, -1.0448785 , -1.0460389 ,  1.1863779 ,  2.1875956 ,
#        -0.14900143, -0.26908135,  0.3215658 ,  0.04575264, -0.4019754 ],
#       dtype=float32)

# %%
len(model_cbow.wv['king']) # length of word/ token in tweet
# Out:
# 225

# %% [markdown]
# # Function to convert a tweet(broken into tokens) into a vector of size 225

# %%
def Tweet_vector(Tweet_tokenized):
    vector = np.zeros(Encoding_dim).reshape((1,Encoding_dim)) # 1 row ; size columns
    count = 0
    for token in Tweet_tokenized:
        try:
            vector += model_cbow.wv[token].reshape((1,Encoding_dim))  # 1 row ; Size columns
            count += 1
        except KeyError:  # handling the case where the token is not in vocabulary
            continue      # simply ignore such case
            
    if count != 0:
        vector /= count
        
    return vector

# %% [markdown]
# # convert each tweet into an individual vector of size 225
#
#     so after this we should have a dataset with:
#     Number of rows = number of tweets
#     Number of columns = Encoding_Dim (size of each vector representation an individual tweet)

# %%
Tweetvec_array = np.zeros((len(Tokenized_Tweet), Encoding_dim)) #numpy array of all zeros; contains cols = encoding_dim and rows= no of tweets

#populating the array with corressponding vector representation of tweets
for i in range(len(Tokenized_Tweet)):
    Tweetvec_array[i,:] = Tweet_vector(Tokenized_Tweet[i])  #[i,:] ith row ; ':' means all columns

# %%
Tweetvector = pd.DataFrame(Tweetvec_array)
Tweetvector.shape
# Out:
# (29348, 225)

# %%
Tweetvector.loc[0] #print content of entire row with index 0
# Out:
# 0      0.817877
# 1      1.432254
# 2      0.363570
# 3     -0.309338
# 4     -1.096685
# 5     -0.995644
# 6     -1.254976
# 7      0.215907
# 8     -0.162495
# 9      0.157340
# 10     0.692640
# 11    -0.945204
# 12    -0.030611
# 13     0.731782
# 14     0.809958
# 15     0.529591
# 16    -0.379408
# 17     0.467954
# 18    -0.610880
# 19     0.161241
# 20    -0.541638
# 21    -0.260280
# 22     0.316765
# 23    -0.422912
# 24    -0.081314
# 25     0.214392
# 26    -0.369229
# 27     0.301516
# 28    -0.764310
# 29    -0.026836
#          ...
# 195   -0.640787
# 196   -1.064072
# 197    0.722097
# 198   -0.073014
# 199   -0.387816
# 200   -0.219368
# 201    0.306234
# 202    0.799231
# 203   -0.350603
# 204   -0.852184
# 205   -0.695551
# 206    0.004794
# 207   -0.413762
# 208    0.754193
# 209    0.078255
# 210    0.782817
# 211   -0.524252
# 212    1.094811
# 213   -0.141211
# 214   -0.444128
# 215    0.133686
# 216    0.192441
# 217    0.151021
# 218    0.131588
# 219   -0.033487
# 220    0.643215
# 221    0.355040
# 222   -0.272265
# 223   -0.174932
# 224    0.910907
# Name: 0, Length: 225, dtype: float64

# %%
tweets_label.shape  # lables
# Out:
# (29348,)

# %%
Tweetvector.shape # vector representation of tweets
# Out:
# (29348, 225)

# %% [markdown]
# # Finally the Data is ready to be used to train a Classification Algorithm
#
#     Here we are going to support vector machine
#     and for the multiclass classification we are going to the polynomial kernal of the Supoort vector Classifer (SVC)

# %% [markdown]
# # Split data into training and test sets :

# %%
Tweet_train, Tweet_test, sentiment_train, sentiment_test = train_test_split(Tweetvector, tweets_label, random_state=101, test_size=0.20)

# %%
print(Tweet_train.shape)
print(Tweet_test.shape)
print(sentiment_train.shape)
print(sentiment_test.shape)
# Out:
# (23478, 225)
# (5870, 225)
# (23478,)
# (5870,)

# %% [markdown]
# # Parameters of the model
#
#     C: regularization parameter;
#        it trades off misclassification of training examples against simplicity of the decision surface.
#        A low C makes the decision surface smooth, while a high C aims at classifying all training examples correctly.
#
#     gamma : {‘scale’, ‘auto’} or float, default=’scale’
#             Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’.
#             if gamma='scale' (default) is passed then it uses 1 / (n_features * X.var()) as value of gamma,
#             if ‘auto’, uses 1 / n_features.
#
#     kernel: Specify the type of kernel to be used.
#             {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
#
#     degree: int value, default=3
#             Degree of the polynomial kernel function (‘poly’). Ignored by all other kernels.
#
#     random_state : to account for reproduceable results
#
#     max_iter : the maximum number of iteration the algorithm is allowed to perform in order to corverge(minimize the cost)

# %%
training_accuracy = []
test_accuracy = []
C = [0.01,0.1,0.25,0.5,0.75,1.0,1.25,1.5,2.0,2.5]

for c in C:
    clf = SVC(kernel ='poly',C=c, degree=2,gamma='scale',max_iter=30000,random_state=101)
    clf.fit(Tweet_train,sentiment_train)
    test_accuracy.append( accuracy_score(sentiment_test, clf.predict(Tweet_test)) )
    training_accuracy.append( accuracy_score(sentiment_train, clf.predict(Tweet_train)) )
    print ("Accuracy for training set with regularization parameter C = %s is : %.3f" % (c, accuracy_score(sentiment_train, clf.predict(Tweet_train))))
    print ("Accuracy for test set with regularization parameter C = %s is : %.3f" % (c, accuracy_score(sentiment_test, clf.predict(Tweet_test))))
    print ("\n")
# Out:
# Accuracy for training set with regularization parameter C = 0.01 is : 0.442
# Accuracy for test set with regularization parameter C = 0.01 is : 0.434
#
#
# Accuracy for training set with regularization parameter C = 0.1 is : 0.690
# Accuracy for test set with regularization parameter C = 0.1 is : 0.661
#
#
# Accuracy for training set with regularization parameter C = 0.25 is : 0.742
# Accuracy for test set with regularization parameter C = 0.25 is : 0.695
#
#
# Accuracy for training set with regularization parameter C = 0.5 is : 0.779
# Accuracy for test set with regularization parameter C = 0.5 is : 0.714
#
#
# Accuracy for training set with regularization parameter C = 0.75 is : 0.800
# Accuracy for test set with regularization parameter C = 0.75 is : 0.725
#
#
# Accuracy for training set with regularization parameter C = 1.0 is : 0.815
# Accuracy for test set with regularization parameter C = 1.0 is : 0.727
#
#
# Accuracy for training set with regularization parameter C = 1.25 is : 0.826
# Accuracy for test set with regularization parameter C = 1.25 is : 0.727
#
#
# Accuracy for training set with regularization parameter C = 1.5 is : 0.836
# Accuracy for test set with regularization parameter C = 1.5 is : 0.728
#
#
# Accuracy for training set with regularization parameter C = 2.0 is : 0.851
# Accuracy for test set with regularization parameter C = 2.0 is : 0.733
#
#
# Accuracy for training set with regularization parameter C = 2.5 is : 0.863
# Accuracy for test set with regularization parameter C = 2.5 is : 0.732

# %%
my_dpi = 100 # dots per inch .. (resolution)
plt.figure(figsize=(1000/my_dpi, 400/my_dpi), dpi = my_dpi) # to enlarge the plot (can be omitted)

plt.plot(C, training_accuracy, label = 'Accuracy of the Training Set')
plt.plot(C, test_accuracy, label = 'Accuracy of the Test Set')
plt.ylabel('Accuracy')
plt.xticks(C)
plt.xlabel('Regularization Parameter')
plt.legend()
plt.grid()

# %% [markdown]
# # using one vs rest to compare results with count vectorizer

# %%
for c in [0.01,0.1,0.25,0.5,0.75,1.0,1.25,1.5]:
    clf = OneVsRestClassifier(LinearSVC(C=c,max_iter=20000,random_state=101),n_jobs = 1)
    clf.fit(Tweet_train,sentiment_train)
    print ("Accuracy for training set with regularization parameter C = %.3f is : %.3f" % ( c,accuracy_score(sentiment_train, clf.predict(Tweet_train))))
    print ("Accuracy for test set with regularization parameter C = %.3f is : %.3f" % (c, accuracy_score(sentiment_test, clf.predict(Tweet_test))))
    print ("\n")
# Out:
# Accuracy for training set with regularization parameter C = 0.010 is : 0.664
# Accuracy for test set with regularization parameter C = 0.010 is : 0.661
#
#
# Accuracy for training set with regularization parameter C = 0.100 is : 0.665
# Accuracy for test set with regularization parameter C = 0.100 is : 0.660
#
#
# Accuracy for training set with regularization parameter C = 0.250 is : 0.665
# Accuracy for test set with regularization parameter C = 0.250 is : 0.660
#
#
# Accuracy for training set with regularization parameter C = 0.500 is : 0.665
# Accuracy for test set with regularization parameter C = 0.500 is : 0.660
#
#
# Accuracy for training set with regularization parameter C = 0.750 is : 0.665
# Accuracy for test set with regularization parameter C = 0.750 is : 0.659
#
#
# Accuracy for training set with regularization parameter C = 1.000 is : 0.665
# Accuracy for test set with regularization parameter C = 1.000 is : 0.659
#
#
# Accuracy for training set with regularization parameter C = 1.250 is : 0.665
# Accuracy for test set with regularization parameter C = 1.250 is : 0.659
#
#
# Accuracy for training set with regularization parameter C = 1.500 is : 0.665
# Accuracy for test set with regularization parameter C = 1.500 is : 0.659

# %% [markdown]
# # The Value of C (Regularization Parameter)  selected for this model = 0.75
#
#         observations:
#         value of degree = 2 is best , increasing to 3 overfits the model as training accuracy is 90%+
#         but test set accuracy is below 50%
#
#         value of regularization parameter 'C' is not increased beyond 2.5, as after doing so the model fails to converge
#         even after 30,000 iterations

# %%
clf = SVC(kernel ='poly',C=0.75, degree=2,gamma='scale',max_iter=20000,random_state=101)
clf.fit(Tweet_train,sentiment_train)
print ("Accuracy for training set with regularization param C= 0.75 is : %.3f" % ( accuracy_score(sentiment_train, clf.predict(Tweet_train))))
print ("Accuracy for test set with regularization param C= 0.75 is : %.3f" % ( accuracy_score(sentiment_test, clf.predict(Tweet_test))))
print ("\n")
# Out:
# Accuracy for training set with regularization param C= 0.75 is : 0.800
# Accuracy for test set with regularization param C= 0.75 is : 0.725

# %% [markdown]
# # Making Predictions and Evaluating the Classifier

# %%
sentiment_test
# Out:
# array([0, 1, 0, ..., 2, 1, 0], dtype=int64)

# %%
sentimentdf=  pd.DataFrame( sentiment_test)

# %% [markdown]
# # Function to Convert numeric labels to their String equivalent

# %%
def convert_sent(number):
    if number == 2 :
        return 'Neutral'
    elif number == 1:
        return 'positive'
    else :
        return 'negetive'

# %% [markdown]
# # Making Prediction of sentiments on test set and comparing with actual sentiments

# %%
predictions = clf.predict(Tweet_test)
Id = sentimentdf.index
predicted_sentiments = pd.DataFrame(predictions, Id , columns = ['Predicted_sentiments'])
actual_sentiments = pd.DataFrame(sentiment_test, Id, columns = ['Actual_sentiments'])
predictions_comparions=actual_sentiments.merge(predicted_sentiments, how = 'outer', left_index = True, right_index = True)
predictions_comparions.head(10)
# Out:
#    Actual_sentiments  Predicted_sentiments
# 0  0                  0
# 1  1                  1
# 2  0                  2
# 3  2                  2
# 4  1                  0
# 5  1                  1
# 6  0                  0
# 7  2                  2
# 8  0                  1
# 9  0                  0

# %%
predictions_comparions['Actual_sentiments'] =predictions_comparions['Actual_sentiments'].apply(convert_sent)
predictions_comparions['Predicted_sentiments'] =predictions_comparions['Predicted_sentiments'].apply(convert_sent)
predictions_comparions.head(10)
# Out:
#   Actual_sentiments Predicted_sentiments
# 0  negetive          negetive
# 1  positive          positive
# 2  negetive          Neutral
# 3  Neutral           Neutral
# 4  positive          negetive
# 5  positive          positive
# 6  negetive          negetive
# 7  Neutral           Neutral
# 8  negetive          positive
# 9  negetive          negetive

# %%
predictions_comparions.groupby(['Actual_sentiments']).count()
# Out:
#                    Predicted_sentiments
# Actual_sentiments
# Neutral            1850
# negetive           1920
# positive           2100

# %% [markdown]
# # Confusion Matrix And calculating Precision Recall and F1 Score
#
#     In the Confusion Matrix : Negetive = 0 ; Positive = 1 ; Neutral = 2 (class Labels)
#                 Row represents actual Sentiments while the columns represents the predicted sentiments
#
#                 1st row : 1st column :Actual Sentiment = Negetive ; Predicted Sentiment = Negetive
#                 1st row : 2nd column :Actual Sentiment = Negetive ; Predicted Sentiment = Positive
#                 1st row : 3rd column :Actual Sentiment = Negetive ; Predicted Sentiment = Neutral
#
#                 2nd row : 1st column :Actual Sentiment = Positive ; Predicted Sentiment = Negetive
#                 2nd row : 2nd column :Actual Sentiment = Positive ; Predicted Sentiment = Positive
#                 2nd row : 3rd column :Actual Sentiment = Positive ; Predicted Sentiment = Neutral
#
#                 3rd row : 1st column :Actual Sentiment = Neutral ; Predicted Sentiment = Negetive
#                 3rd row : 2nd column :Actual Sentiment = Neutral ; Predicted Sentiment = Positive
#                 3rd row : 3rd column :Actual Sentiment = Neutral ; Predicted Sentiment = Neutral

# %%
cm  = confusion_matrix(sentiment_test,predictions )
print(cm)
# Out:
# [[1384  356  180]
#  [ 326 1599  175]
#  [ 297  282 1271]]

# %% [markdown]
# # Precision Recall & F1 Score:
#
#     Precison = True Postive/(Total predicted Positive) || True Postive/(True Positive + False Positive)
#                Precision talks about how precise/accurate the model is, i.e. out of total predicted positive,
#                how many of them are actual positive.
#
#     Recall = True Positive/(Total actual Positive) || True Postive/(True Positive + False Negetive)
#              Recall calculates how many of the Actual Positives the model captures by labeling it
#              as Positive (True Positive)
#
#     F1 Score = (2 * Precision * Recall) / (Precision + Recall)

# %%
precision = precision_score(sentiment_test, predictions, average='macro')
print('Precision of the Classifier Model : %.3f' % precision)
recall = recall_score(sentiment_test, predictions, average='macro')
print('Recall of the Classifier Model : %.3f' %recall)
f1 = f1_score(sentiment_test, predictions, average='macro')
print('F1 Score of the Classifier Model : %.3f' %f1)
# Out:
# Precision of the Classifier Model : 0.729
# Recall of the Classifier Model : 0.723
# F1 Score of the Classifier Model : 0.725

# %% [markdown]
# # PREDICT SENTIMENT FROM CUSTOM TWEETS
#     (Tweets not in the dataset , neither in training nor in test set)
#
#     Test case 1:
#             "its a sad night for @RealMadridCF we lost the game 2-1, but we will come back stronger next time #Hala_Madrid",
#              "@SDER You are a bully,you deserverd to be punished",
#              "yes,, @IndianCricket team are the champions of the world 😍 #WINNERS #WORLDCHAPMPS",
#              " THE FOOD WAS ENJOYABLE 😊 😊",
#              "rest in peace !! #RIP 😢 😢"
#
#      Test Case 2:
#              "Donald trump , i have no idea how this man became the president of the country #STUPID #WORST_PRESIDENT",
#              "@iamrohit you were right ...Kolkata is rightfully called the City of Joy..",
#              "Hell yeah,, @Rogerfedrrer win his 20th Grand Slam #legend",
#              "The food could not have been more bad, One of the worst restaurant i have dined at ,
#              the food actually teatsed like shit",
#              "Machine learning is one of the most intersteing feilds to work on",
#              " The movie was a bit boring and not so intersting for me also it was slow,
#              overall it was below average !!! #Chappak"
#
#       Test Case 3: ... save the test case here for future references

# %%
User_Tweets = ["Donald trump , i have no idea how this man became the president of the country #STUPID #WORST_PRESIDENT",
             "@iamrohit you were right ...Kolkata is rightfully called the City of Joy..",
             "Hell yeah,, @Rogerfedrrer win his 20th Grand Slam #legend",
             " The food could not have been more bad, One of the worst restaurant i have dined at , the food actually teatsed like shit",
             "Machine learning is one of the most intersteing feilds to work on",
             " The movie was a bit boring and not so intersting for me also it was slow , overall it was below average !!! #Chappak"
             ]

IP_Tweets =  pd.DataFrame (User_Tweets,columns=['Input_Tweets'])

# %%
IP_Tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
# Input_Tweets    6 non-null object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
IP_Tweets
# Out:
#                                                                                                                 Input_Tweets
# 0  Donald trump , i have no idea how this man became the president of the country #STUPID #WORST_PRESIDENT
# 1  @iamrohit you were right ...Kolkata is rightfully called the City of Joy..
# 2  Hell yeah,, @Rogerfedrrer win his 20th Grand Slam #legend
# 3   The food could not have been more bad, One of the worst restaurant i have dined at , the food actually teatsed like shit
# 4  Machine learning is one of the most intersteing feilds to work on
# 5   The movie was a bit boring and not so intersting for me also it was slow , overall it was below average !!! #Chappak

# %% [markdown]
# # Pre Process the tweets and convert them into vectors

# %%
IP_Tweets['Input_Tweets'] = IP_Tweets['Input_Tweets'].apply(cleanTxt)
IP_Tweets
# Out:
#                                                                                                             Input_Tweets
# 0  donald trump i have no idea how this man became the president of the country stupid worstpresident
# 1  you were right kolkata is rightfully called the city of joy
# 2  hell yeah win his th grand slam legend
# 3  the food could not have been more bad one of the worst restaurant i have dined at the food actually teatsed like shit
# 4  machine learning is one of the most intersteing feilds to work on
# 5  the movie was a bit boring and not so intersting for me also it was slow overall it was below average chappak

# %%
IP_Tweets['Input_Tweets'] = IP_Tweets['Input_Tweets'].apply(convertEmoji)
IP_Tweets
# Out:
#                                                                                                             Input_Tweets
# 0  donald trump i have no idea how this man became the president of the country stupid worstpresident
# 1  you were right kolkata is rightfully called the city of joy
# 2  hell yeah win his th grand slam legend
# 3  the food could not have been more bad one of the worst restaurant i have dined at the food actually teatsed like shit
# 4  machine learning is one of the most intersteing feilds to work on
# 5  the movie was a bit boring and not so intersting for me also it was slow overall it was below average chappak

# %%
IP_Tweets['Input_Tweets'] = IP_Tweets['Input_Tweets'].apply(Tokenization)
IP_Tweets
# Out:
#                                                               Input_Tweets
# 0  donald trump idea man became president country stupid worstpresident
# 1  right kolkata rightfully called city joy
# 2  hell yeah win th grand slam legend
# 3  food could bad one bad restaurant dined food actually teatsed like shit
# 4  machine learning one intersteing feilds work
# 5  movie bit boring intersting also slow overall average chappak

# %%
IPtweets_array = IP_Tweets['Input_Tweets'].values
IPtweets_array
# Out:
# array(['donald trump idea man became president country stupid worstpresident',
#        'right kolkata rightfully called city joy',
#        'hell yeah win th grand slam legend',
#        'food could bad one bad restaurant dined food actually teatsed like shit',
#        'machine learning one intersteing feilds work',
#        'movie bit boring intersting also slow overall average chappak'],
#       dtype=object)

# %%
Tokenized_IPtweets = [word_tokenize(tweet) for tweet in IPtweets_array]
Tokenized_IPtweets
# Out:
# [['donald',
#   'trump',
#   'idea',
#   'man',
#   'became',
#   'president',
#   'country',
#   'stupid',
#   'worstpresident'],
#  ['right', 'kolkata', 'rightfully', 'called', 'city', 'joy'],
#  ['hell', 'yeah', 'win', 'th', 'grand', 'slam', 'legend'],
#  ['food',
#   'could',
#   'bad',
#   'one',
#   'bad',
#   'restaurant',
#   'dined',
#   'food',
#   'actually',
#   'teatsed',
#   'like',
#   'shit'],
#  ['machine', 'learning', 'one', 'intersteing', 'feilds', 'work'],
#  ['movie',
#   'bit',
#   'boring',
#   'intersting',
#   'also',
#   'slow',
#   'overall',
#   'average',
#   'chappak']]

# %%
IPTweetvec_array = np.zeros((len(Tokenized_IPtweets),Encoding_dim)) #numpy array of all zeros; contains 200 cols and rows= no of tweets

#populating the array with corressponding vector representation of tweets
for i in range(len(Tokenized_IPtweets)):
    IPTweetvec_array[i,:] = Tweet_vector(Tokenized_IPtweets[i])

# %% [markdown]
# # predict Sentiment of these tweets using their coressponding tweet vectors

# %%
pred = clf.predict(IPTweetvec_array)
pred = pred.tolist() # to covert 0,1,2 to pos neg and nuetral (printing output purpose)

for i in range(len(pred)):
    if(pred[i]==0):
        pred[i]=('Negetive')
    elif(pred[i]==1):
        pred[i]='Positive'
    else:
        pred[i]='Neutral'

# %% [markdown]
# # Check Predictions of each given Tweet

# %%
for i in range (len(User_Tweets)):
    print("The sentiment for review :\n",User_Tweets[i],"is :\n",pred[i],"\n")
# Out:
# The sentiment for review :
#  Donald trump , i have no idea how this man became the president of the country #STUPID #WORST_PRESIDENT is :
#  Negetive
#
# The sentiment for review :
#  @iamrohit you were right ...Kolkata is rightfully called the City of Joy.. is :
#  Positive
#
# The sentiment for review :
#  Hell yeah,, @Rogerfedrrer win his 20th Grand Slam #legend is :
#  Positive
#
# The sentiment for review :
#   The food could not have been more bad, One of the worst restaurant i have dined at , the food actually teatsed like shit is :
#  Negetive
#
# The sentiment for review :
#  Machine learning is one of the most intersteing feilds to work on is :
#  Neutral
#
# The sentiment for review :
#   The movie was a bit boring and not so intersting for me also it was slow , overall it was below average !!! #Chappak is :
#  Negetive
